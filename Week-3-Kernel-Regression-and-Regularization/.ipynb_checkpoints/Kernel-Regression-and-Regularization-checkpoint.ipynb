# %% [markdown]
# # Week 3: Kernel Regression and Regularization
#
# ## Lecture 6 (Mon, Jan 25) Kernel Regression
#
# Please see the notes in Canvas for details, but we derived the parameters of a local linear regression model in the neighborhood of the point $x_0$ for $d=1$ by minimizing the weighted squared error loss function,
#
# $$L(\alpha(x_0),\beta(x_0))=\sum\limits_{i=1}^N K_\lambda(x_0,x_i)\left(y_i - \alpha(x_0) - \beta(x_0)x_i\right)^2$$
#
# The function $K_\lambda$ is called a kernel, or weighting, function. Intuitively, it measures how similar two points are. If $x_i$ and $x_0$ are close, the kernel function will be large, so $x_i$ will have a larger impact on the local regression model. A common kernel function is the Gaussian kernel,
#
# $$K_\lambda(x_0,x) = \frac{1}{\lambda}\exp\left(-\frac{\|x-x_0\|_2^2}{2\lambda}\right)$$
#
# We found the parameters of the unknown function $f$ in the vicinity of $x_0$ to be
#
# $$\begin{pmatrix} \alpha(x_0) \\ \beta(x_0)\end{pmatrix} = (X^TW(x_0)X)^{-1}X^TW(x_0)y,$$
#
# where
#
# $$X = \begin{pmatrix}1 & x_1\\ 1 & x_2 \\ \vdots & \vdots \\ 1 & x_n\end{pmatrix}, \quad y = \begin{pmatrix}y_1 \\ y_2 \\ \vdots \\ y_n\end{pmatrix}, \quad W(x_0)=\begin{pmatrix}K_\lambda(x_0,x_1) & & & \\ & K_\lambda(x_0,x_2) & & \\ & & \ddots & \\ & & & K_\lambda(x_0,x_n)\end{pmatrix}$$
#
# where $W(x_0)$ is a diagonal matrix, meaning all entries except the diagonal entries are 0.
#
# And, so, the local linear approximation of the unknown function $f$ at $x_0$ is
#
#
# $$\hat{f}(x_0) = \begin{pmatrix}1 & x_0\end{pmatrix}(X^TW(x_0)X)^{-1}X^TW(x_0)y$$
#
# ## Lecture 7 (Wed, Jan 27) Implementing Kernel Regression

# %% [markdown]
# Let's write a class that will carry out kernel regression to construct local linear regression models. The class will take the $X$ data, $y$ data, and kernel function as inputs.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

def GaussianKernel(x0, x, lam):
    return (1/lam) * np.exp(-np.linalg.norm(x0 - x) / (2 * lam))

class KernelRegression:
    def __init__(self, kernel_function, lam, fit_intercept = True):
        self.kernel_function = kernel_function
        self.fit_intercept = fit_intercept
        self.lam = lam

    def predict(self, x0, X, y):
        # find the number of X points
        n = X.shape[0]
        
        # add a column of ones if needed
        if self.fit_intercept:
            X = np.hstack((np.ones([n,1]), X))

        # construct the kernel matrix
        kernel = np.zeros([n, n])
        
        # populate the kernel matrix
        for i in range(n):
            kernel[i][i] = self.kernel_function(x0, X[i,:], self.lam)
                
        return np.array([1, np.float(x0)]) @ np.linalg.inv((X.T @ kernel @ X)) @ X.T @ kernel @ y

# %% [markdown]
# Let's try it with the shampoo dataset from last week. First, read in the data

# %%
# read the shampoo sales dataset
data = pd.read_csv('data/shampoo.csv')

# save the targets
y = data['Sales'].to_numpy()

# make a column vector of 0s with n elements
X = np.zeros([y.shape[0], 1])

# convert the vector to (0, 1, 2, ..., n)
X[:,0] = [i for i in range(y.shape[0])]

# split the data into train and test sets
(trainX, testX, trainY, testY) = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %% [markdown]
# Next, let's run the kernel regression model at each x value in a reasonable range using the Gaussian kernel with $\lambda\in\{0.1n:n=1,...,100\}$ and plot each.

# %%
lamValues = np.linspace(0.025, 10, 100)

M = lamValues.shape[0]

# allow multiple plots
fig, axes = plt.subplots(nrows = M + 1, figsize = (10, 4*M))

trainMAE = []
testMAE = []

for (j, lam) in enumerate(lamValues):
    model = KernelRegression(GaussianKernel, lam)

    xModel = [i for i in range(int(np.round(1.1 * np.max(X))))]
    yModel = [model.predict(i, trainX, trainY) for i in xModel]

    label = 'Kernel Smoothing for lambda = ' + str(np.round(lam, 2))
    axes[j].scatter(X, y)
    axes[j].plot(xModel, yModel, 'r', label = label)
    axes[j].legend()
    
    # apply the basis functions to the test data and predict with the model
    trainPredictions = [model.predict(i, trainX, trainY) for i in trainX]
    testPredictions = [model.predict(i, trainX, trainY) for i in testX]
    
    # compute the training and test mean absolute error
    trainError = mean_absolute_error(trainY, trainPredictions)
    testError = mean_absolute_error(testY, testPredictions)
    
    # save the training and test mean absolute error
    trainMAE.append(trainError)
    testMAE.append(testError)

    # return quality metrics
    print('lambda:', np.round(lam, 3), '\t\tr^2:', np.round(r2_score(trainY, trainPredictions), 3), '\t\ttrain MAE:', np.round(trainError, 3), '\t\ttest MAE:', np.round(testError, 3))
    
# plot the errors
axes[M].plot(range(M), trainMAE, label = 'Training Mean Absolute Error')
axes[M].plot(range(M), testMAE, label = 'Testing Mean Absolute Error')
axes[M].legend()
# Out:
# lambda: 0.025 		r^2: 0.906 		train MAE: 27.749 		test MAE: 62.18
# lambda: 0.126 		r^2: 0.845 		train MAE: 39.621 		test MAE: 53.187
# lambda: 0.227 		r^2: 0.838 		train MAE: 41.857 		test MAE: 51.014
# lambda: 0.327 		r^2: 0.835 		train MAE: 43.324 		test MAE: 49.475
# lambda: 0.428 		r^2: 0.832 		train MAE: 44.423 		test MAE: 48.152
# lambda: 0.529 		r^2: 0.828 		train MAE: 45.371 		test MAE: 46.875
# lambda: 0.63 		r^2: 0.825 		train MAE: 46.288 		test MAE: 45.603
# lambda: 0.73 		r^2: 0.822 		train MAE: 47.28 		test MAE: 44.353
# lambda: 0.831 		r^2: 0.819 		train MAE: 48.155 		test MAE: 44.288
# lambda: 0.932 		r^2: 0.816 		train MAE: 48.937 		test MAE: 44.263
# lambda: 1.033 		r^2: 0.813 		train MAE: 49.641 		test MAE: 44.239
# lambda: 1.133 		r^2: 0.81 		train MAE: 50.278 		test MAE: 44.211
# lambda: 1.234 		r^2: 0.807 		train MAE: 50.857 		test MAE: 44.18
# lambda: 1.335 		r^2: 0.804 		train MAE: 51.384 		test MAE: 44.142
# lambda: 1.436 		r^2: 0.801 		train MAE: 51.865 		test MAE: 44.099
# lambda: 1.536 		r^2: 0.798 		train MAE: 52.304 		test MAE: 44.049
# lambda: 1.637 		r^2: 0.796 		train MAE: 52.705 		test MAE: 43.994
# lambda: 1.738 		r^2: 0.793 		train MAE: 53.071 		test MAE: 43.933
# lambda: 1.839 		r^2: 0.791 		train MAE: 53.406 		test MAE: 43.868
# lambda: 1.939 		r^2: 0.789 		train MAE: 53.712 		test MAE: 43.797
# lambda: 2.04 		r^2: 0.787 		train MAE: 53.992 		test MAE: 43.723
# lambda: 2.141 		r^2: 0.784 		train MAE: 54.248 		test MAE: 43.644
# lambda: 2.242 		r^2: 0.782 		train MAE: 54.482 		test MAE: 43.563
# lambda: 2.342 		r^2: 0.78 		train MAE: 54.696 		test MAE: 43.479
# lambda: 2.443 		r^2: 0.779 		train MAE: 54.893 		test MAE: 43.393
# lambda: 2.544 		r^2: 0.777 		train MAE: 55.073 		test MAE: 43.381
# lambda: 2.645 		r^2: 0.775 		train MAE: 55.239 		test MAE: 43.438
# lambda: 2.745 		r^2: 0.773 		train MAE: 55.391 		test MAE: 43.487
# lambda: 2.846 		r^2: 0.772 		train MAE: 55.531 		test MAE: 43.526
# lambda: 2.947 		r^2: 0.77 		train MAE: 55.66 		test MAE: 43.559
# lambda: 3.048 		r^2: 0.768 		train MAE: 55.778 		test MAE: 43.585
# lambda: 3.148 		r^2: 0.767 		train MAE: 55.888 		test MAE: 43.605
# lambda: 3.249 		r^2: 0.765 		train MAE: 55.989 		test MAE: 43.621
# lambda: 3.35 		r^2: 0.764 		train MAE: 56.083 		test MAE: 43.632
# lambda: 3.451 		r^2: 0.763 		train MAE: 56.17 		test MAE: 43.639
# lambda: 3.552 		r^2: 0.761 		train MAE: 56.251 		test MAE: 43.643
# lambda: 3.652 		r^2: 0.76 		train MAE: 56.326 		test MAE: 43.644
# lambda: 3.753 		r^2: 0.759 		train MAE: 56.417 		test MAE: 43.642
# lambda: 3.854 		r^2: 0.758 		train MAE: 56.528 		test MAE: 43.638
# lambda: 3.955 		r^2: 0.756 		train MAE: 56.634 		test MAE: 43.632
# lambda: 4.055 		r^2: 0.755 		train MAE: 56.736 		test MAE: 43.625
# lambda: 4.156 		r^2: 0.754 		train MAE: 56.833 		test MAE: 43.616
# lambda: 4.257 		r^2: 0.753 		train MAE: 56.927 		test MAE: 43.605
# lambda: 4.358 		r^2: 0.752 		train MAE: 57.016 		test MAE: 43.66
# lambda: 4.458 		r^2: 0.751 		train MAE: 57.103 		test MAE: 43.715
# lambda: 4.559 		r^2: 0.75 		train MAE: 57.186 		test MAE: 43.766
# lambda: 4.66 		r^2: 0.749 		train MAE: 57.265 		test MAE: 43.814
# lambda: 4.761 		r^2: 0.748 		train MAE: 57.342 		test MAE: 43.859
# lambda: 4.861 		r^2: 0.747 		train MAE: 57.416 		test MAE: 43.901
# lambda: 4.962 		r^2: 0.746 		train MAE: 57.487 		test MAE: 43.941
# lambda: 5.063 		r^2: 0.745 		train MAE: 57.556 		test MAE: 43.978
# lambda: 5.164 		r^2: 0.744 		train MAE: 57.622 		test MAE: 44.013
# lambda: 5.264 		r^2: 0.743 		train MAE: 57.687 		test MAE: 44.047
# lambda: 5.365 		r^2: 0.742 		train MAE: 57.748 		test MAE: 44.078
# lambda: 5.466 		r^2: 0.741 		train MAE: 57.808 		test MAE: 44.108
# lambda: 5.567 		r^2: 0.741 		train MAE: 57.866 		test MAE: 44.136
# lambda: 5.667 		r^2: 0.74 		train MAE: 57.922 		test MAE: 44.163
# lambda: 5.768 		r^2: 0.739 		train MAE: 57.976 		test MAE: 44.188
# lambda: 5.869 		r^2: 0.738 		train MAE: 58.029 		test MAE: 44.212
# lambda: 5.97 		r^2: 0.738 		train MAE: 58.08 		test MAE: 44.235
# lambda: 6.07 		r^2: 0.737 		train MAE: 58.136 		test MAE: 44.257
# lambda: 6.171 		r^2: 0.736 		train MAE: 58.204 		test MAE: 44.277
# lambda: 6.272 		r^2: 0.735 		train MAE: 58.27 		test MAE: 44.297
# lambda: 6.373 		r^2: 0.735 		train MAE: 58.335 		test MAE: 44.315
# lambda: 6.473 		r^2: 0.734 		train MAE: 58.398 		test MAE: 44.333
# lambda: 6.574 		r^2: 0.733 		train MAE: 58.459 		test MAE: 44.35
# lambda: 6.675 		r^2: 0.733 		train MAE: 58.518 		test MAE: 44.366
# lambda: 6.776 		r^2: 0.732 		train MAE: 58.576 		test MAE: 44.382
# lambda: 6.877 		r^2: 0.731 		train MAE: 58.633 		test MAE: 44.396
# lambda: 6.977 		r^2: 0.731 		train MAE: 58.688 		test MAE: 44.41
# lambda: 7.078 		r^2: 0.73 		train MAE: 58.742 		test MAE: 44.424
# lambda: 7.179 		r^2: 0.73 		train MAE: 58.795 		test MAE: 44.437
# lambda: 7.28 		r^2: 0.729 		train MAE: 58.846 		test MAE: 44.449
# lambda: 7.38 		r^2: 0.728 		train MAE: 58.896 		test MAE: 44.461
# lambda: 7.481 		r^2: 0.728 		train MAE: 58.945 		test MAE: 44.472
# lambda: 7.582 		r^2: 0.727 		train MAE: 58.993 		test MAE: 44.483
# lambda: 7.683 		r^2: 0.727 		train MAE: 59.04 		test MAE: 44.493
# lambda: 7.783 		r^2: 0.726 		train MAE: 59.086 		test MAE: 44.503
# lambda: 7.884 		r^2: 0.726 		train MAE: 59.13 		test MAE: 44.512
# lambda: 7.985 		r^2: 0.725 		train MAE: 59.174 		test MAE: 44.521
# lambda: 8.086 		r^2: 0.725 		train MAE: 59.217 		test MAE: 44.53
# lambda: 8.186 		r^2: 0.724 		train MAE: 59.259 		test MAE: 44.539
# lambda: 8.287 		r^2: 0.724 		train MAE: 59.3 		test MAE: 44.547
# lambda: 8.388 		r^2: 0.723 		train MAE: 59.34 		test MAE: 44.554
# lambda: 8.489 		r^2: 0.723 		train MAE: 59.379 		test MAE: 44.562
# lambda: 8.589 		r^2: 0.722 		train MAE: 59.418 		test MAE: 44.569
# lambda: 8.69 		r^2: 0.722 		train MAE: 59.455 		test MAE: 44.576
# lambda: 8.791 		r^2: 0.721 		train MAE: 59.492 		test MAE: 44.583
# lambda: 8.892 		r^2: 0.721 		train MAE: 59.528 		test MAE: 44.589
# lambda: 8.992 		r^2: 0.72 		train MAE: 59.564 		test MAE: 44.595
# lambda: 9.093 		r^2: 0.72 		train MAE: 59.598 		test MAE: 44.601
# lambda: 9.194 		r^2: 0.72 		train MAE: 59.633 		test MAE: 44.607
# lambda: 9.295 		r^2: 0.719 		train MAE: 59.666 		test MAE: 44.612
# lambda: 9.395 		r^2: 0.719 		train MAE: 59.699 		test MAE: 44.618
# lambda: 9.496 		r^2: 0.718 		train MAE: 59.731 		test MAE: 44.623
# lambda: 9.597 		r^2: 0.718 		train MAE: 59.762 		test MAE: 44.628
# lambda: 9.698 		r^2: 0.717 		train MAE: 59.793 		test MAE: 44.633
# lambda: 9.798 		r^2: 0.717 		train MAE: 59.824 		test MAE: 44.637
# lambda: 9.899 		r^2: 0.717 		train MAE: 59.853 		test MAE: 44.642
# lambda: 10.0 		r^2: 0.716 		train MAE: 59.883 		test MAE: 44.646

# %% [markdown]
# As you can see, with a smaller $\lambda$ value, the fitted curve has some very sharp curves as the nearby points exert a pulling force on the locally linear curve. But, as we increase $\lambda$, the more smoothing we see in the predicted curve--as points further away from the input $x_0$ have more impact. Increasing $\lambda$ results in smoother and smoother curves (hence, the name kernel *smoothing*), which become nearer to a linear fit.
