# %% [markdown]
# # Homework 2
#
# ## Problem 1
#
# Fit a linear basis function model or a kernel smoothing model to the data and tune the hyperparameters of the model. (Run at least 20 experiments.)

# %%
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

# %%
# read the data from the csv file
data = pd.read_csv('../data/homework-2-data.csv')

# delete rows with duplicate X's
data = data.drop_duplicates(subset = 'X', keep = 'first')

# print the data
data
# Out:
#           X       Y
# 0     2.333   3.681
# 1    25.311   6.795
# 2    24.702   6.366
# 3    14.917  10.402
# 4     4.872   7.166
# ..      ...     ...
# 197  10.091   9.677
# 198   4.236   6.743
# 199  41.747  -5.310
# 200  43.194  -5.414
# 201  22.319   4.232
#
# [191 rows x 2 columns]

# %%
# extract the inputs X and outputs Y
X = data['X'].to_numpy()
Y = data['Y'].to_numpy()

# convert X to a n-by-1 matrix
X = np.atleast_2d(X).T

# plot the data
plt.scatter(X,Y)

# %% [markdown]
# Let's try a kernel smoothing model. First, bring in the `KernelRegression` class from the lecture. (Week 3 - Lecture 7)

# %%
def GaussianKernel(x0, x, lam):
    return (1/lam) * np.exp(-np.linalg.norm(x0 - x) / (2 * lam ** 2))

class KernelRegression:
    def __init__(self, kernel_function, lam, fit_intercept = True):
        self.kernel_function = kernel_function
        self.fit_intercept = fit_intercept
        self.lam = lam

    def predict(self, x0, X, y):
        # find the number of X points
        n = X.shape[0]
        
        # add a column of ones if needed
        if self.fit_intercept:
            X = np.hstack((np.ones([n,1]), X))

        # construct the kernel matrix
        kernel = np.zeros([n, n])
        
        # populate the kernel matrix
        for i in range(n):
            kernel[i][i] = self.kernel_function(x0, X[i,:], self.lam)
        
        # return the prediction at point x0
        return np.array([1, np.float(x0)]) @ np.linalg.inv((X.T @ kernel @ X)) @ X.T @ kernel @ y

# %% [markdown]
# Next, let's see if we can tune the hyperparameter $\lambda$ by splitting the data into training, dev, and test sets and running experiments on the dev set.

# %%
# split the data into train and test sets
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.4)
devX, testX, devY, testY = train_test_split(testX, testY, test_size = 0.5)

lamValues = np.linspace(0.187, 0.5, 10)

M = lamValues.shape[0]

# allow multiple plots
fig, axes = plt.subplots(nrows = M + 1, figsize = (10, 4*M))

trainMAE = []
devMAE = []

for (j, lam) in enumerate(lamValues):
    model = KernelRegression(GaussianKernel, lam)

    # compute the model coordinates
    xModel = np.linspace(0, 1.1 * np.max(X), 1000)
    yModel = [model.predict(i, trainX, trainY) for i in xModel]

    # plot the model
    label = 'Kernel Smoothing for lambda = ' + str(np.round(lam, 2))
    axes[j].scatter(trainX, trainY, label = 'Training Data')
    axes[j].scatter(devX, devY, label = 'Dev Data')
    axes[j].plot(xModel, yModel, 'r', label = label)
    axes[j].legend()
    
    # apply the functions to the test data and predict with the model
    trainPredictions = [model.predict(i, trainX, trainY) for i in trainX]
    devPredictions = [model.predict(i, trainX, trainY) for i in devX]
    
    # compute the training and test mean absolute error
    trainError = mean_absolute_error(trainY, trainPredictions)
    devError = mean_absolute_error(devY, devPredictions)
    
    # save the training and test mean absolute error
    trainMAE.append(trainError)
    devMAE.append(devError)

    # return quality metrics
    print('lambda:', np.round(lam, 3), '\t\tr^2:', np.round(r2_score(trainY, trainPredictions), 3),
          '\t\ttrain MAE:', np.round(trainError, 3), '\t\tdev MAE:', np.round(devError, 3))
    
# plot the errors
axes[M].plot(range(M), trainMAE, label = 'Training Mean Absolute Error')
axes[M].plot(range(M), devMAE, label = 'Dev Mean Absolute Error')
axes[M].legend()
# Out:
# <ipython-input-57-a0d361ce9b83>:26: RuntimeWarning: overflow encountered in matmul
#   return np.array([1, np.float(x0)]) @ np.linalg.inv((X.T @ kernel @ X)) @ X.T @ kernel @ y
# <ipython-input-57-a0d361ce9b83>:26: RuntimeWarning: invalid value encountered in matmul
#   return np.array([1, np.float(x0)]) @ np.linalg.inv((X.T @ kernel @ X)) @ X.T @ kernel @ y
# lambda: 0.187 		r^2: 0.912 		train MAE: 1.219 		dev MAE: 1.241
# lambda: 0.222 		r^2: 0.906 		train MAE: 1.288 		dev MAE: 1.287
# lambda: 0.257 		r^2: 0.901 		train MAE: 1.364 		dev MAE: 1.33
# lambda: 0.291 		r^2: 0.895 		train MAE: 1.439 		dev MAE: 1.366
# lambda: 0.326 		r^2: 0.888 		train MAE: 1.512 		dev MAE: 1.423
# lambda: 0.361 		r^2: 0.882 		train MAE: 1.577 		dev MAE: 1.491
# lambda: 0.396 		r^2: 0.876 		train MAE: 1.631 		dev MAE: 1.568
# lambda: 0.43 		r^2: 0.869 		train MAE: 1.682 		dev MAE: 1.636
# lambda: 0.465 		r^2: 0.863 		train MAE: 1.734 		dev MAE: 1.694
# lambda: 0.5 		r^2: 0.857 		train MAE: 1.784 		dev MAE: 1.746

# %% [markdown]
# One final test on the test set with the best value of $\lambda$.

# %%
model = KernelRegression(GaussianKernel, 0.187)

# compute the model coordinates
xModel = np.linspace(0, 1.1 * np.max(X), 1000)
yModel = [model.predict(i, trainX, trainY) for i in xModel]

# plot the model
label = 'Kernel Smoothing for lambda = ' + str(0.187)
plt.scatter(testX, testY, label = 'Test Data')
plt.plot(xModel, yModel, 'r', label = label)
plt.legend()
    
# apply the functions to the test data and predict with the model
trainPredictions = [model.predict(i, trainX, trainY) for i in trainX]
testPredictions = [model.predict(i, trainX, trainY) for i in testX]
    
# compute the training and test mean absolute error
trainError = mean_absolute_error(trainY, trainPredictions)
testError = mean_absolute_error(testY, testPredictions)

# return quality metrics
print('lambda:', 0.187, '\t\tr^2:', np.round(r2_score(trainY, trainPredictions), 3),
      '\t\ttrain MAE:', np.round(trainError, 3), '\t\ttest MAE:', np.round(testError, 3))
# Out:
# <ipython-input-57-a0d361ce9b83>:26: RuntimeWarning: overflow encountered in matmul
#   return np.array([1, np.float(x0)]) @ np.linalg.inv((X.T @ kernel @ X)) @ X.T @ kernel @ y
# <ipython-input-57-a0d361ce9b83>:26: RuntimeWarning: invalid value encountered in matmul
#   return np.array([1, np.float(x0)]) @ np.linalg.inv((X.T @ kernel @ X)) @ X.T @ kernel @ y
# lambda: 0.187 		r^2: 0.912 		train MAE: 1.219 		test MAE: 1.455

# %% [markdown]
# ## Problem 2
#
# Let's simply modify the `gradientDescent` function from class. (Week 4, Lecture 9)

# %%
def computeGradient(f, x, h):
    # create a zero vector for the gradient
    n = len(x)
    gradient = np.zeros(n)
    
    # save f(x) so we don't need to compute it so frequently
    fx = f(x)
    
    # approximate the gradient
    for i in range(n):
        xUp = x.copy()
        
        # add h to the ith component of x
        xUp[i] += h
        
        # approximate the ith partial derivative
        gradient[i] = (f(xUp) - fx)/h
    
    # return the gredient
    return gradient

# run gradient descent and output the 
def gradientDescent(f, dimension, points, alpha, gamma, acceleration, h, tolerance, maxIterations, verbose = 1):
    x0 = np.random.uniform(-1, 1, size = (points, dimension))
    gradient = np.zeros([points, dimension])
    functionValue = np.zeros([points, 1])
    
    bestError = np.array([100000, 100000])
    for (i, x) in enumerate(x0):
        v = 0
        for counter in range(maxIterations):
            
            # update the gradient
            gradient[i] = computeGradient(f, x, h)

            # stop if the norm of the gradient is near 0
            if np.linalg.norm(gradient[i]) < tolerance:
                if verbose:
                    print('Gradient descent took', counter, 'iterations to converge')
                # return the approximate critical value x
                #return x
                break

            # if we do not converge, print a message
            elif counter == maxIterations-1:
                if verbose:
                    print("Gradient descent failed")
                # return x anyway
                #return x
                break
                
            # add Nesterov acceleration
            if acceleration:
                gradient[i] = computeGradient(f, x - gamma * v, h)

            # take a step with momentum
            v = gamma*v + alpha*gradient[i]
            x -= v
            
            functionValue[i] = f(x)

            if functionValue[i] < bestError[1]:
                bestError = [x, functionValue[i]]
    
    #if verbose:
    print('The minimum function value is', bestError[1])
        
    return bestError[0]

# %% [markdown]
# Let's run it with different values of gamma and with/without Nesterov acceleration on a simple example.

# %%
f = lambda x: x[0] ** 2
for gamma in np.linspace(0.0, 1.0, 11):
    print('\ngamma = ', np.round(gamma, 1))
    print('\nWITHOUT and then WITH Nesterov Acceleration:')
    print(gradientDescent(f, 1, 1, 0.01, gamma, 0, 0.0001, 0.01, 100000))
    print(gradientDescent(f, 1, 1, 0.01, gamma, 1, 0.0001, 0.01, 100000))
# Out:
# gamma =  0.0
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 72 iterations to converge
# The minimum function value is [2.46128536e-05]
# [-0.00496113]
# Gradient descent took 234 iterations to converge
# The minimum function value is [2.3721651e-05]
# [0.00487049]
#
# gamma =  0.1
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 210 iterations to converge
# The minimum function value is [2.41009835e-05]
# [0.00490928]
# Gradient descent took 197 iterations to converge
# The minimum function value is [2.40135451e-05]
# [0.00490036]
#
# gamma =  0.2
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 203 iterations to converge
# The minimum function value is [2.36259101e-05]
# [0.00486065]
# Gradient descent took 192 iterations to converge
# The minimum function value is [2.44010993e-05]
# [-0.00493975]
#
# gamma =  0.3
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 153 iterations to converge
# The minimum function value is [2.36681917e-05]
# [0.004865]
# Gradient descent took 164 iterations to converge
# The minimum function value is [2.42664339e-05]
# [-0.0049261]
#
# gamma =  0.4
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 114 iterations to converge
# The minimum function value is [2.42334198e-05]
# [-0.00492275]
# Gradient descent took 129 iterations to converge
# The minimum function value is [2.40884279e-05]
# [0.004908]
#
# gamma =  0.5
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 107 iterations to converge
# The minimum function value is [2.3501979e-05]
# [-0.00484788]
# Gradient descent took 127 iterations to converge
# The minimum function value is [2.52797304e-05]
# [-0.0050279]
#
# gamma =  0.6
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 95 iterations to converge
# The minimum function value is [2.24956657e-05]
# [0.00474296]
# Gradient descent took 99 iterations to converge
# The minimum function value is [2.26160678e-05]
# [0.00475564]
#
# gamma =  0.7
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 64 iterations to converge
# The minimum function value is [2.36273466e-05]
# [-0.0048608]
# Gradient descent took 67 iterations to converge
# The minimum function value is [2.36602996e-05]
# [-0.00486419]
#
# gamma =  0.8
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 23 iterations to converge
# The minimum function value is [1.7272735e-05]
# [-0.00415605]
# Gradient descent took 27 iterations to converge
# The minimum function value is [1.61368594e-05]
# [-0.00401707]
#
# gamma =  0.9
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 37 iterations to converge
# The minimum function value is [2.7177168e-07]
# [0.00052132]
# Gradient descent took 15 iterations to converge
# The minimum function value is [1.5584997e-05]
# [-0.00394778]
#
# gamma =  1.0
#
# WITHOUT and then WITH Nesterov Acceleration:
# Gradient descent took 55 iterations to converge
# The minimum function value is [4.17783956e-07]
# [-0.00064636]
# Gradient descent took 11 iterations to converge
# The minimum function value is [5.65032318e-06]
# [-0.00237704]

# %% [markdown]
# Let's also test with 10 different random starting points.

# %%
f = lambda x: x[0] ** 2
for gamma in np.linspace(0.0, 1.0, 11):
    print('\ngamma = ', np.round(gamma, 1))
    print(gradientDescent(f, 1, 10, 0.01, gamma, 1, 0.0001, 0.01, 100000, verbose = 0))
# Out:
# gamma =  0.0
# The minimum function value is [2.36897553e-05]
# [0.00486721]
#
# gamma =  0.1
# The minimum function value is [2.34483004e-05]
# [0.00484234]
#
# gamma =  0.2
# The minimum function value is [2.373854e-05]
# [0.00487222]
#
# gamma =  0.3
# The minimum function value is [2.33898625e-05]
# [0.00483631]
#
# gamma =  0.4
# The minimum function value is [2.30964607e-05]
# [0.00480588]
#
# gamma =  0.5
# The minimum function value is [2.2557197e-05]
# [0.00474944]
#
# gamma =  0.6
# The minimum function value is [2.25380983e-05]
# [0.00474743]
#
# gamma =  0.7
# The minimum function value is [2.20219319e-05]
# [-0.00469275]
#
# gamma =  0.8
# The minimum function value is [7.45086962e-10]
# [2.72962811e-05]
#
# gamma =  0.9
# The minimum function value is [7.4594933e-06]
# [-0.00273121]
#
# gamma =  1.0
# The minimum function value is [2.75922866e-07]
# [0.00052528]

# %% [markdown]
# Let's use it for OLS with the `OrdinaryLeastSquaresGradient` class (modified for momentum and Nesterov acceleration) we constructed in lecture. (Week 4, Lecture 9)

# %%
class OrdinaryLeastSquaresGradient:
        
    # fit the model to the data
    def fit(self, X, y, x0, alpha, gamma, acceleration, h, tolerance, maxIterations):
        
        # save the training data
        X = np.hstack((np.ones([X.shape[0], 1]), X))
        
        # save the training labels
        output = y
        
        # find the theta values that minimize the sum of squared errors via gradient descent
        L = lambda theta: ((X @ theta).T - y.T) @ (X @ theta - y)
        self.theta = gradientDescent(L, x0, alpha, gamma, acceleration, h, tolerance, maxIterations)
                
    # predict the output from testing data
    def predict(self, X):
        # initialize an empty matrix to store the predicted outputs
        yPredicted = np.empty([X.shape[0],1])
        
        # append a column of ones at the beginning of X
        X = np.hstack((np.ones([X.shape[0],1]), X))
        
        # apply the function f with the values of theta from the fit function to each testing datapoint (rows of X)
        for row in range(X.shape[0]):
            yPredicted[row] = self.theta @ X[row,]
            
        return yPredicted

# %%
# import the data from the csv file to an numpy array
data = pd.read_csv('../../data/US_State_Data.csv', sep=',').to_numpy()

# save into X and Y
X = np.array(data[:,1:8], dtype=float)
y = np.array(data[:,8], dtype=float)

# split the data into training and test sets
(trainX, testX, trainY, testY) = train_test_split(X, y, test_size = 0.25, random_state = 1)

# standardize the data
trainX = scale(trainX)
testX = scale(testX)

# instantiate an OLS model
model = OrdinaryLeastSquaresGradient()

for gamma in np.linspace(0, 0.99, 20):
    print('\ngamma = ', np.round(gamma, 2))
    
    # with acceleration
    print('\n============================= ACCELERATION OFF =============================')
    
    # fit the model to the training data (find the theta parameters)
    model.fit(trainX, trainY, [0, 0, 0, 0, 0, 0, 0, 0], alpha = 0.005, gamma = gamma, acceleration = 0,
              h = 0.001, tolerance = 0.01, maxIterations = 100000)

    # return the predicted outputs for the datapoints in the training set
    trainPredictions = model.predict(trainX)

    # print the coefficient of determination r^2
    print('\nThe r^2 score is', r2_score(trainY, trainPredictions))

    # print quality metrics
    print('The mean absolute error on the training set is', mean_absolute_error(trainY, trainPredictions))

    # return the predicted outputs for the datapoints in the test set
    predictions = model.predict(testX)

    # print quality metrics
    print('The mean absolute error on the test set is', mean_absolute_error(testY, predictions))
    
    # with acceleration
    print('\n============================= ACCELERATION ON =============================')
    
    model.fit(trainX, trainY, [0, 0, 0, 0, 0, 0, 0, 0], alpha = 0.005, gamma = gamma, acceleration = 1,
              h = 0.001, tolerance = 0.01, maxIterations = 100000)

    # return the predicted outputs for the datapoints in the training set
    trainPredictions = model.predict(trainX)

    # print the coefficient of determination r^2
    print('\nThe r^2 score is', r2_score(trainY, trainPredictions))

    # print quality metrics
    print('The mean absolute error on the training set is', mean_absolute_error(trainY, trainPredictions))

    # return the predicted outputs for the datapoints in the test set
    predictions = model.predict(testX)

    # print quality metrics
    print('The mean absolute error on the test set is', mean_absolute_error(testY, predictions))
# Out:
# gamma =  0.0
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 164 iterations to converge
#
# The r^2 score is 0.4035247531789167
# The mean absolute error on the training set is 3.6674121484727515
# The mean absolute error on the test set is 4.004939515553437
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 164 iterations to converge
#
# The r^2 score is 0.4035247531789167
# The mean absolute error on the training set is 3.6674121484727515
# The mean absolute error on the test set is 4.004939515553437
#
# gamma =  0.05
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 155 iterations to converge
#
# The r^2 score is 0.4035247532629196
# The mean absolute error on the training set is 3.667412092761507
# The mean absolute error on the test set is 4.004941741569685
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 155 iterations to converge
#
# The r^2 score is 0.40352475303588775
# The mean absolute error on the training set is 3.6674122498038817
# The mean absolute error on the test set is 4.004936108795179
#
# gamma =  0.1
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 146 iterations to converge
#
# The r^2 score is 0.4035247533841686
# The mean absolute error on the training set is 3.6674120105418537
# The mean absolute error on the test set is 4.004944939470316
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 146 iterations to converge
#
# The r^2 score is 0.40352475289853573
# The mean absolute error on the training set is 3.667412346601013
# The mean absolute error on the test set is 4.004932900311569
#
# gamma =  0.16
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 136 iterations to converge
#
# The r^2 score is 0.4035247529785725
# The mean absolute error on the training set is 3.6674123025848004
# The mean absolute error on the test set is 4.00493532125266
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 138 iterations to converge
#
# The r^2 score is 0.4035247533668481
# The mean absolute error on the training set is 3.66741202023233
# The mean absolute error on the test set is 4.00494437840422
#
# gamma =  0.21
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 127 iterations to converge
#
# The r^2 score is 0.40352475319639636
# The mean absolute error on the training set is 3.667412156760148
# The mean absolute error on the test set is 4.004940908345221
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 129 iterations to converge
#
# The r^2 score is 0.4035247533206454
# The mean absolute error on the training set is 3.6674120564014006
# The mean absolute error on the test set is 4.004943386745382
#
# gamma =  0.26
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 118 iterations to converge
#
# The r^2 score is 0.4035247535050731
# The mean absolute error on the training set is 3.667411943037438
# The mean absolute error on the test set is 4.004948933531558
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 120 iterations to converge
#
# The r^2 score is 0.40352475332509286
# The mean absolute error on the training set is 3.667412057539458
# The mean absolute error on the test set is 4.004943703236664
#
# gamma =  0.31
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 108 iterations to converge
#
# The r^2 score is 0.4035247532499937
# The mean absolute error on the training set is 3.667412138727145
# The mean absolute error on the test set is 4.00494317287105
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 111 iterations to converge
#
# The r^2 score is 0.4035247534098835
# The mean absolute error on the training set is 3.6674120025571195
# The mean absolute error on the test set is 4.0049460887353
#
# gamma =  0.36
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 98 iterations to converge
#
# The r^2 score is 0.40352475308142366
# The mean absolute error on the training set is 3.667412274493312
# The mean absolute error on the test set is 4.004939822255102
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 102 iterations to converge
#
# The r^2 score is 0.40352475361927875
# The mean absolute error on the training set is 3.667411857885469
# The mean absolute error on the test set is 4.004951738171685
#
# gamma =  0.42
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 88 iterations to converge
#
# The r^2 score is 0.40352475311263336
# The mean absolute error on the training set is 3.667412273977781
# The mean absolute error on the test set is 4.004941595277775
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 92 iterations to converge
#
# The r^2 score is 0.4035247532164854
# The mean absolute error on the training set is 3.6674121629158254
# The mean absolute error on the test set is 4.004942365438587
#
# gamma =  0.47
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 78 iterations to converge
#
# The r^2 score is 0.4035247535527581
# The mean absolute error on the training set is 3.667411980675917
# The mean absolute error on the test set is 4.004953817430694
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 82 iterations to converge
#
# The r^2 score is 0.4035247529860362
# The mean absolute error on the training set is 3.667412347016529
# The mean absolute error on the test set is 4.004937772020422
#
# gamma =  0.52
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 67 iterations to converge
#
# The r^2 score is 0.40352475376736086
# The mean absolute error on the training set is 3.667411859595139
# The mean absolute error on the test set is 4.0049614181345765
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 72 iterations to converge
#
# The r^2 score is 0.40352475323280945
# The mean absolute error on the training set is 3.667412203440212
# The mean absolute error on the test set is 4.004945273584809
#
# gamma =  0.57
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 54 iterations to converge
#
# The r^2 score is 0.4035247541181508
# The mean absolute error on the training set is 3.6674103581108084
# The mean absolute error on the test set is 4.004958746499022
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 61 iterations to converge
#
# The r^2 score is 0.4035247534083919
# The mean absolute error on the training set is 3.667412130499388
# The mean absolute error on the test set is 4.004952379582644
#
# gamma =  0.63
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 55 iterations to converge
#
# The r^2 score is 0.40352476034774365
# The mean absolute error on the training set is 3.667402078598384
# The mean absolute error on the test set is 4.005186809183074
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 47 iterations to converge
#
# The r^2 score is 0.40352475257155485
# The mean absolute error on the training set is 3.667412972815058
# The mean absolute error on the test set is 4.004939633536015
#
# gamma =  0.68
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 60 iterations to converge
#
# The r^2 score is 0.40352475756026385
# The mean absolute error on the training set is 3.667407760892987
# The mean absolute error on the test set is 4.00518419787826
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 41 iterations to converge
#
# The r^2 score is 0.4035247598821
# The mean absolute error on the training set is 3.6673961457765145
# The mean absolute error on the test set is 4.005356829843381
#
# gamma =  0.73
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 65 iterations to converge
#
# The r^2 score is 0.4035247651376599
# The mean absolute error on the training set is 3.6673832593680653
# The mean absolute error on the test set is 4.005179890532156
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 47 iterations to converge
#
# The r^2 score is 0.40352475195302784
# The mean absolute error on the training set is 3.667414878739246
# The mean absolute error on the test set is 4.0049900807537275
#
# gamma =  0.78
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 99 iterations to converge
#
# The r^2 score is 0.40352475505064755
# The mean absolute error on the training set is 3.6674150907090635
# The mean absolute error on the test set is 4.005169892004176
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 46 iterations to converge
#
# The r^2 score is 0.4035247446670125
# The mean absolute error on the training set is 3.667415979778662
# The mean absolute error on the test set is 4.0053572788588525
#
# gamma =  0.83
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 110 iterations to converge
#
# The r^2 score is 0.4035247618190655
# The mean absolute error on the training set is 3.6674017612266887
# The mean absolute error on the test set is 4.005166652790119
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 68 iterations to converge
#
# The r^2 score is 0.4035247489117789
# The mean absolute error on the training set is 3.667417781490648
# The mean absolute error on the test set is 4.004968892598706
#
# gamma =  0.89
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 190 iterations to converge
#
# The r^2 score is 0.4035247555905278
# The mean absolute error on the training set is 3.6674149142427424
# The mean absolute error on the test set is 4.005172980893591
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 81 iterations to converge
#
# The r^2 score is 0.4035247628044728
# The mean absolute error on the training set is 3.667390526681944
# The mean absolute error on the test set is 4.00534480658285
#
# gamma =  0.94
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 378 iterations to converge
#
# The r^2 score is 0.403524754444739
# The mean absolute error on the training set is 3.6674148414832537
# The mean absolute error on the test set is 4.005162775676597
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 108 iterations to converge
#
# The r^2 score is 0.4035247514242899
# The mean absolute error on the training set is 3.667414532730298
# The mean absolute error on the test set is 4.005182899589507
#
# gamma =  0.99
#
# ============================= ACCELERATION OFF =============================
# Gradient descent took 1883 iterations to converge
#
# The r^2 score is 0.4035247592543699
# The mean absolute error on the training set is 3.6673758866837978
# The mean absolute error on the test set is 4.005128930764439
#
# ============================= ACCELERATION ON =============================
# Gradient descent took 177 iterations to converge
#
# The r^2 score is 0.403524766883108
# The mean absolute error on the training set is 3.6673936001532677
# The mean absolute error on the test set is 4.005058680699578

# %% [markdown]
# Note that the number of iterations gets smaller with momentum only until $\gamma=0.57$ (54 iterations) and acceleration starts to have a further reduction starting at $\gamma=0.63$ reaching a minimum of 41 iterations at $\gamma=0.68$.

# %% [markdown]
# ## Problem 3
#
# Let's bring in our `GaussianRBFnetwork` class from the lecture. (Week 4, Lecture 11)
#
# We will modify the code to include $L^1$ and $L^2$ penalties, momentum, and Nesterov acceleration.

# %%
# create a RBF network class
class GaussianRBFnetwork:
    # initialize the model
    def __init__(self, d, M, alpha = 0.001, lambda1 = 0, lambda2 = 0,
                 gamma = 0, acceleration = 0, initialization = 'uniform'):
        
        # the dimension of the datapoints
        self.d = d
        
        # the number of radial basis functions
        self.M = M
                
        # the learning rate
        self.alpha = alpha
        
        # the L1 penalty coefficient
        self.lambda1 = lambda1
        
        # the L2 penalty coefficient
        self.lambda2 = lambda2
        
        # the momentum hyperparameter
        self.gamma = gamma
        
        # flag for Nesterov acceleration
        self.acceleration = acceleration
        
        # initialize the parameters
        if initialization == 'uniform':
            theta = 10 * np.random.uniform(-1, 1, size = (M + 1))
            lam = 10 * np.random.uniform(0, 1, size = (M))
            xi = 10 * np.random.uniform(-1, 1, size = (M, d))

        # save the initial parameters
        self.theta = theta
        self.lam = lam
        self.xi = xi
                
    # fit the model to some data X with labels y
    def fit(self, X, y, epochs = 1000, update = 10, annealing = False):
        self.n = X.shape[0]
        
        # save the training data
        X = np.hstack((np.ones([self.n, 1]), X))
        
        # initialize the kernel-weighted inputs
        XK = np.zeros([self.n, self.M])
        XK = np.hstack((np.ones([self.n, 1]), XK))
        
        # save the learning rate locally
        alpha = copy.copy(self.alpha)
        
        t = 0
        l = 0
        x = 0
        
        # run gradient descent with exact gradients
        for j in range(epochs):
            
            # adjust terms if we use Nesterov acceleration
            if self.acceleration:
                theta = self.theta - self.gamma * t
                lam = self.lam - self.gamma * l
                xi = self.xi - self.gamma * x
            else:
                theta = self.theta
                lam = self.lam
                xi = self.xi
            
            # compute the gradients ==================================================================================
            
            # theta gradient ################################
            
            # compute the kernel-weighted inputs
            for i in range(self.n):
                for k in range(self.M):
                    XK[i, k + 1] = self.GaussianKernel(X[i, 1:], self.xi[k], self.lam[k])
                        
            # training predictions         
            predictions = XK @ theta
            
            # compute the error
            error = predictions - y

            # compute theweighted error
            weightederror = np.atleast_2d(error).T * XK
            
            # compute the theta partial derivatives
            thetagrad = np.sum(weightederror, axis = 0)
            
            # lambda gradient ################################
            
            # compute the lambda partial derivatives
            term3 = np.zeros([self.n, self.M])
            for k in range(self.M):
                term3[:, k] = ((np.linalg.norm(xi[k] - X[:,1:], axis = 1)/lam[k]) ** 2 - 1) * theta[k]/lam[k]
            
            lamerror = term3 * weightederror[:, 1:]
            lamgrad = np.sum(lamerror, axis = 0)

            # xi gradient ####################################
            
            # compute the xi partial derivatives
            term4 = np.zeros([self.n, self.M, self.d])
            for k in range(self.M):
                for l in range(self.d):
                    term4[:, k, l] = (X[:, l] - xi[k, l]) * theta[k] / lam[k] ** 2

            xierror = term4 * np.atleast_3d(weightederror[:, 1:])
            xigrad = np.sum(xierror, axis = 0)
            
            # weight updates ===========================================================================================
            
            # add gradients of L1 and L2 penalties to gradients
            thetagrad += self.lambda1 * np.sign(theta) + 2 * self.lambda2 * theta
            lamgrad += self.lambda1 * np.sign(lam) + 2 * self.lambda2 * lam
            xigrad += self.lambda1 * np.sign(xi) + 2 * self.lambda2 * xi
            
            # weight updates with momentum or Nesterov acceleration
            t = self.gamma * t + self.alpha * thetagrad
            self.theta -= t
            
            l = self.gamma * l + self.alpha * lamgrad
            self.lam -= l
            
            x = self.gamma * x + self.alpha * xigrad
            self.xi -= x

            # ensure lambdas are positive
            self.lam = np.abs(self.lam)
                        
            # if the annealing variable is True, shrink the learning rate over time
            if annealing:
                self.alpha = (1 - j / epochs) * alpha
                
            # print a status update periodically
            if j % update == 0:
                print('Epoch', j, '\tLoss =', np.sum(error ** 2)/self.M)

    # compute predictions
    def predict(self, X):
        n = X.shape[0]
        X = np.hstack((np.ones([n, 1]), X))
        
        # initialize the kernel-weighted inputs
        XK = np.zeros([n, self.M])
        XK = np.hstack((np.ones([n, 1]), XK))
        
        # compute the kernel-weighted inputs
        for i in range(n):
            for k in range(self.M):
                XK[i, k + 1] = self.GaussianKernel(X[i, 1:], self.xi[k], self.lam[k])
                
        # training predictions
        predictions = XK @ self.theta

        return predictions
    
    # the Gaussian radial basis function
    def GaussianKernel(self, x, xi, lam):
        return (1/lam) * np.exp(-np.linalg.norm(x - xi) ** 2 / (2 * lam ** 2))

# %%
# read the data from the csv file
data = pd.read_csv('../data/homework-2-data.csv')

# delete rows with duplicate X's
data = data.drop_duplicates(subset = 'X', keep = 'first')

# extract the inputs X and outputs Y
X = data['X'].to_numpy()
Y = data['Y'].to_numpy()

# convert X to a n-by-1 matrix
X = np.atleast_2d(X).T

trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.4)
devX, testX, devY, testY = train_test_split(testX, testY, test_size = 0.5)

# %%
model = GaussianRBFnetwork(d = 1, M = 10, alpha = 0.01, gamma = 0.9, acceleration = 0,
                           lambda1 = 0, lambda2 = 0, initialization = 'uniform')

# fit the model
model.fit(trainX, trainY, epochs = 10000, update = 1000)

# predict the outputs
trainPredictions = model.predict(trainX)
devPredictions = model.predict(devX)

# compute the training and test mean absolute error
trainError = mean_absolute_error(trainY, trainPredictions)
devError = mean_absolute_error(devY, devPredictions)

# return quality metrics
print('The r^2 score is', r2_score(trainPredictions, trainY))
print('The mean absolute error on the training set is', trainError)
print('The mean absolute error on the dev set is', devError)

xModel = np.atleast_2d(np.linspace(0, 1.1 * np.max(X), 100)).T
yModel = model.predict(xModel)

# plot the training data
plt.scatter(trainX, trainY)

# plot the model
plt.plot(xModel, yModel, 'r')
# Out:
# Epoch 0 	Loss = 1309.5669202832125
# Epoch 1000 	Loss = 176.07043593432311
# Epoch 2000 	Loss = 149.25226965229652
# Epoch 3000 	Loss = 140.67826369080777
# Epoch 4000 	Loss = 136.98589565089702
# Epoch 5000 	Loss = 135.0576400623506
# Epoch 6000 	Loss = 133.92267078139656
# Epoch 7000 	Loss = 133.19726785661356
# Epoch 8000 	Loss = 132.70415134940436
# Epoch 9000 	Loss = 132.35204828130944
# The r^2 score is 0.6965672992906944
# The mean absolute error on the training set is 2.453351903944599
# The mean absolute error on the dev set is 2.054782173459007

# %% [markdown]
# The fit isn't amazing, but it certainly captures general trends in the data. (More experiments should be done with cross-validation for hyperparameter tuning.)
