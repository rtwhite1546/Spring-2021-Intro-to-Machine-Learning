# %% [markdown]
# # Week 8: LDA, QDA, and PCA
#
# This week, we will learn how to implement linear discriminant analysis (LDA) and quadratic discriminant analysis (QDA) for classification as well as begin learning about **principal components analysis (PCA)**, an **unsupervised** learning method for reducing the dimension of our data in an effective way.
#
# ## Lecture 20: Implementing LDA and QDA
#
# Today, we will apply some of the theory from the last class to use linear discriminant analysis (and quadratic discriminant analysis) on some real classification problems. Let's import some libraries first.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import time

from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import mnist

# %% [markdown]
# ### LDA Class

# %%
from sklearn.base import BaseEstimator, ClassifierMixin, TransformerMixin

class DA(ClassifierMixin, BaseEstimator):
    def __init__(self, equalCovariances = True, alpha = 1, gamma = 1):
        # if True, LDA
        # if False, QDA
        self.equalCovariances = equalCovariances
        
        # if less than 1, regularized DA (requires QDA)
        self.alpha = alpha
        
        # if less than 1, shrinkage
        self.gamma = gamma
        
    def fit(self, X, Y):
        # find the unique labels
        uniqueY = np.unique(Y)
        
        # find the dimensions
        n = X.shape[0]
        self.d = X.shape[1]
        self.k = uniqueY.shape[0]

        # initialize the variables
        self.prior = np.zeros([self.k, 1])
        self.mu = np.zeros([self.k, 1, self.d])
        
        # compute the covariance matrix
        if self.equalCovariances or self.gamma < 1 or self.alpha < 1:
            mu = np.mean(X, axis = 0)
            Xbar = X - mu
            self.Sig = (1/n) * Xbar.T @ Xbar
            
            # shrinkage
            if self.gamma < 1:
                self.Sig = self.gamma * self.Sig + (1 - self.gamma) * np.diag(self.Sig)
                
            self.invCov = np.linalg.inv(self.Sig)
        
        if not self.equalCovariances:
            self.Sigma = np.zeros([self.k, self.d, self.d])            
        
        for i, y in enumerate(uniqueY):
            # extract a class of datapoints from X
            Xi = X[Y == y]
            
            # compute the size of each class
            ni = Xi.shape[0]
            
            # compute the priors
            self.prior[i] = ni / n
                        
            # compute the feature means within the class
            self.mu[i] = np.mean(Xi, axis = 0)
            
            # compute separate covariances for QDA
            if not self.equalCovariances:
                # compute the centered data
                XiBar = Xi - self.mu[i]
            
                # compute the class sample covariance
                self.Sigma[i] = (1/ni) * XiBar.T @ XiBar
                
                # regularization
                if self.alpha < 1:
                    self.Sigma[i] = self.alpha * self.Sigma[i] + (1 - self.alpha) * self.Sig
                
        
    def predict(self, X):
        n = X.shape[0]
        
        discriminants = np.zeros([n, self.k])
        
        for i, x in enumerate(X):
            x = np.atleast_2d(x).T
            
            for j in range(self.k):
                if not self.equalCovariances:
                    self.invCov = np.linalg.inv(self.Sigma[j])

                discriminants[i][j] = x.T @ self.invCov @ self.mu[j].T - (1/2) * self.mu[j] @ self.invCov @ self.mu[j].T + np.log(self.prior[j])

            
        predictions = np.argmax(discriminants, axis = 1)
        
        return predictions
    
    def score(self, X, y, sample_weight = None):
        return accuracy_score(y, self.predict(X), sample_weight = sample_weight)

# %% [markdown]
# ### Example: Randomly Generated Points

# %%
# number of points to generate
numberOfPoints = 500

# generate points from class 0
mean1 = np.array([-1, -1])
covariance1 = np.array([[5, 0], [0, 5]])
X1 = np.random.multivariate_normal(mean1, covariance1, numberOfPoints)

# generate points from class 1
mean2 = np.array([3, 3])
covariance2 = np.array([[5, 3], [3, 5]])
X2 = np.random.multivariate_normal(mean2, covariance2, numberOfPoints)

# generate points from class 2
mean3 = np.array([-2, 5])
covariance3 = np.array([[5, 3], [3, 5]])
X3 = np.random.multivariate_normal(mean3, covariance3, numberOfPoints)

# stack the points
X = np.vstack((X1, X2, X3))

# create a vector of the labels
Y = np.hstack((numberOfPoints * [0], numberOfPoints * [1], numberOfPoints * [2]))

# randomly choose 75% of the data to be the training set and 25% for the testing set
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.25, random_state = 1)

# plot the training set
plt.scatter(trainX[:,0], trainX[:,1], c = trainY, marker = '.')

# %% [markdown]
# #### Using Our DA method...

# %%
# fit the model to the training data
model = DA()
model.fit(trainX,trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

plt.scatter(trainX[:,0], trainX[:,1], c = trainY, marker = '.')

# print quality metrics
print('\nClassification Report:\n\n', classification_report(testY, predictedY))
print('\nConfusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY), annot = True)
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       120
#            1       0.91      0.83      0.87       127
#            2       0.93      0.93      0.93       128
#
#     accuracy                           0.88       375
#    macro avg       0.88      0.88      0.88       375
# weighted avg       0.89      0.88      0.88       375
#
#
# Confusion Matrix:

# %% [markdown]
# Let's try with QDA.

# %%
# fit the model to the training data
model = DA(equalCovariances = False)
model.fit(trainX,trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

plt.scatter(trainX[:,0], trainX[:,1], c = trainY, marker = '.')

# print quality metrics
print('\nClassification Report:\n\n', classification_report(testY, predictedY))
print('\nConfusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY), annot = True)
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       120
#            1       0.90      0.84      0.87       127
#            2       0.93      0.98      0.95       128
#
#     accuracy                           0.89       375
#    macro avg       0.89      0.89      0.89       375
# weighted avg       0.89      0.89      0.89       375
#
#
# Confusion Matrix:

# %%
# initialize accuracy and hyperparameter list
bestAccuracy = [0, 0, 0]

# test regularization hyperparameters 0.00, 0.01, ..., 0.19
for i in range(1, 11):
    for j in range(1, 11):
        alpha = i/10
        gamma = j/10

        # build the QDA classifier
        model = DA(False, alpha, gamma)

        # fit the QDA classifier to the training data
        model.fit(trainX, trainY)
        
        # compute the test predictions
        predictedY = model.predict(testX)

        # find the mean cross-validation accuracy
        mean_cv_scores = np.mean(cross_val_score(model, trainX, trainY, cv = 5))

        # print quality metrics
        print('Mean CV accuracy for parameters', alpha, gamma, 'is', mean_cv_scores)

        # save the hyperparameter reg_param if better than found before
        if mean_cv_scores > bestAccuracy[0]:
            bestAccuracy = [mean_cv_scores, alpha, gamma]
        
print('\nThe best dev accuracy', bestAccuracy[0], 'occured with alpha =', bestAccuracy[1], 'and gamma =', bestAccuracy[2])
        
# build the QDA classifier
model = DA(False, bestAccuracy[1], bestAccuracy[2])

# fit the QDA classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTest Classification Report for the best hyperparameters:\n\n', classification_report(testY, predictedY))

print('\nTest Confusion Matrix:\n')
sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# Mean CV accuracy for parameters 0.1 0.1 is 0.8391111111111111
# Mean CV accuracy for parameters 0.1 0.2 is 0.8462222222222222
# Mean CV accuracy for parameters 0.1 0.3 is 0.8480000000000001
# Mean CV accuracy for parameters 0.1 0.4 is 0.8542222222222222
# Mean CV accuracy for parameters 0.1 0.5 is 0.8533333333333333
# Mean CV accuracy for parameters 0.1 0.6 is 0.8533333333333333
# Mean CV accuracy for parameters 0.1 0.7 is 0.8533333333333333
# Mean CV accuracy for parameters 0.1 0.8 is 0.8560000000000001
# Mean CV accuracy for parameters 0.1 0.9 is 0.8533333333333333
# Mean CV accuracy for parameters 0.1 1.0 is 0.8533333333333333
# Mean CV accuracy for parameters 0.2 0.1 is 0.8426666666666666
# Mean CV accuracy for parameters 0.2 0.2 is 0.8462222222222222
# Mean CV accuracy for parameters 0.2 0.3 is 0.8480000000000001
# Mean CV accuracy for parameters 0.2 0.4 is 0.8542222222222222
# Mean CV accuracy for parameters 0.2 0.5 is 0.8533333333333333
# Mean CV accuracy for parameters 0.2 0.6 is 0.8542222222222222
# Mean CV accuracy for parameters 0.2 0.7 is 0.8533333333333333
# Mean CV accuracy for parameters 0.2 0.8 is 0.8560000000000001
# Mean CV accuracy for parameters 0.2 0.9 is 0.8542222222222223
# Mean CV accuracy for parameters 0.2 1.0 is 0.8533333333333333
# Mean CV accuracy for parameters 0.3 0.1 is 0.841777777777778
# Mean CV accuracy for parameters 0.3 0.2 is 0.8462222222222222
# Mean CV accuracy for parameters 0.3 0.3 is 0.8506666666666668
# Mean CV accuracy for parameters 0.3 0.4 is 0.855111111111111
# Mean CV accuracy for parameters 0.3 0.5 is 0.8542222222222222
# Mean CV accuracy for parameters 0.3 0.6 is 0.855111111111111
# Mean CV accuracy for parameters 0.3 0.7 is 0.8542222222222222
# Mean CV accuracy for parameters 0.3 0.8 is 0.8542222222222223
# Mean CV accuracy for parameters 0.3 0.9 is 0.8542222222222223
# Mean CV accuracy for parameters 0.3 1.0 is 0.8533333333333333
# Mean CV accuracy for parameters 0.4 0.1 is 0.8426666666666666
# Mean CV accuracy for parameters 0.4 0.2 is 0.8453333333333333
# Mean CV accuracy for parameters 0.4 0.3 is 0.8506666666666668
# Mean CV accuracy for parameters 0.4 0.4 is 0.8542222222222222
# Mean CV accuracy for parameters 0.4 0.5 is 0.8533333333333333
# Mean CV accuracy for parameters 0.4 0.6 is 0.8542222222222223
# Mean CV accuracy for parameters 0.4 0.7 is 0.8533333333333333
# Mean CV accuracy for parameters 0.4 0.8 is 0.8542222222222223
# Mean CV accuracy for parameters 0.4 0.9 is 0.8560000000000001
# Mean CV accuracy for parameters 0.4 1.0 is 0.8542222222222222
# Mean CV accuracy for parameters 0.5 0.1 is 0.8462222222222223
# Mean CV accuracy for parameters 0.5 0.2 is 0.8480000000000001
# Mean CV accuracy for parameters 0.5 0.3 is 0.8533333333333333
# Mean CV accuracy for parameters 0.5 0.4 is 0.8560000000000001
# Mean CV accuracy for parameters 0.5 0.5 is 0.8542222222222223
# Mean CV accuracy for parameters 0.5 0.6 is 0.8560000000000001
# Mean CV accuracy for parameters 0.5 0.7 is 0.8551111111111112
# Mean CV accuracy for parameters 0.5 0.8 is 0.8560000000000001
# Mean CV accuracy for parameters 0.5 0.9 is 0.8586666666666666
# Mean CV accuracy for parameters 0.5 1.0 is 0.8577777777777778
# Mean CV accuracy for parameters 0.6 0.1 is 0.8488888888888889
# Mean CV accuracy for parameters 0.6 0.2 is 0.8515555555555556
# Mean CV accuracy for parameters 0.6 0.3 is 0.8542222222222223
# Mean CV accuracy for parameters 0.6 0.4 is 0.8568888888888889
# Mean CV accuracy for parameters 0.6 0.5 is 0.8568888888888889
# Mean CV accuracy for parameters 0.6 0.6 is 0.8568888888888889
# Mean CV accuracy for parameters 0.6 0.7 is 0.8560000000000001
# Mean CV accuracy for parameters 0.6 0.8 is 0.8568888888888889
# Mean CV accuracy for parameters 0.6 0.9 is 0.8586666666666668
# Mean CV accuracy for parameters 0.6 1.0 is 0.8586666666666666
# Mean CV accuracy for parameters 0.7 0.1 is 0.8515555555555556
# Mean CV accuracy for parameters 0.7 0.2 is 0.8533333333333333
# Mean CV accuracy for parameters 0.7 0.3 is 0.857777777777778
# Mean CV accuracy for parameters 0.7 0.4 is 0.8577777777777778
# Mean CV accuracy for parameters 0.7 0.5 is 0.8577777777777778
# Mean CV accuracy for parameters 0.7 0.6 is 0.8568888888888889
# Mean CV accuracy for parameters 0.7 0.7 is 0.8586666666666666
# Mean CV accuracy for parameters 0.7 0.8 is 0.8577777777777778
# Mean CV accuracy for parameters 0.7 0.9 is 0.8577777777777778
# Mean CV accuracy for parameters 0.7 1.0 is 0.8586666666666668
# Mean CV accuracy for parameters 0.8 0.1 is 0.855111111111111
# Mean CV accuracy for parameters 0.8 0.2 is 0.8560000000000001
# Mean CV accuracy for parameters 0.8 0.3 is 0.8586666666666668
# Mean CV accuracy for parameters 0.8 0.4 is 0.8586666666666668
# Mean CV accuracy for parameters 0.8 0.5 is 0.8586666666666668
# Mean CV accuracy for parameters 0.8 0.6 is 0.8586666666666666
# Mean CV accuracy for parameters 0.8 0.7 is 0.8586666666666668
# Mean CV accuracy for parameters 0.8 0.8 is 0.8586666666666666
# Mean CV accuracy for parameters 0.8 0.9 is 0.8577777777777778
# Mean CV accuracy for parameters 0.8 1.0 is 0.8577777777777778
# Mean CV accuracy for parameters 0.9 0.1 is 0.857777777777778
# Mean CV accuracy for parameters 0.9 0.2 is 0.857777777777778
# Mean CV accuracy for parameters 0.9 0.3 is 0.857777777777778
# Mean CV accuracy for parameters 0.9 0.4 is 0.8586666666666668
# Mean CV accuracy for parameters 0.9 0.5 is 0.8586666666666668
# Mean CV accuracy for parameters 0.9 0.6 is 0.8586666666666668
# Mean CV accuracy for parameters 0.9 0.7 is 0.8577777777777778
# Mean CV accuracy for parameters 0.9 0.8 is 0.8586666666666668
# Mean CV accuracy for parameters 0.9 0.9 is 0.8586666666666668
# Mean CV accuracy for parameters 0.9 1.0 is 0.8568888888888889
# Mean CV accuracy for parameters 1.0 0.1 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.2 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.3 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.4 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.5 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.6 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.7 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.8 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 0.9 is 0.8577777777777778
# Mean CV accuracy for parameters 1.0 1.0 is 0.8577777777777778
#
# The best dev accuracy 0.8586666666666668 occured with alpha = 0.6 and gamma = 0.9
#
# Test Classification Report for the best hyperparameters:
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       120
#            1       0.91      0.84      0.88       127
#            2       0.94      0.95      0.94       128
#
#     accuracy                           0.89       375
#    macro avg       0.89      0.89      0.89       375
# weighted avg       0.89      0.89      0.89       375
#
#
# Test Confusion Matrix:

# %% [markdown]
# #### `scikit-learn` Implementations
#
# Now that we fully see how LDA and QDA work, we will rely on the optimized `scikit-learn` implementations of LDA and QDA.

# %%
# fit the model to the training data
model = LinearDiscriminantAnalysis()
model.fit(trainX,trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

plt.scatter(trainX[:,0], trainX[:,1], c = trainY, marker = '.')

# print quality metrics
print('\nClassification Report:\n\n', classification_report(testY, predictedY))
print('\nConfusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY), annot = True)
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       120
#            1       0.92      0.84      0.88       127
#            2       0.94      0.95      0.94       128
#
#     accuracy                           0.89       375
#    macro avg       0.89      0.89      0.89       375
# weighted avg       0.89      0.89      0.89       375
#
#
# Confusion Matrix:

# %%
# initialize accuracy and hyperparameter list
bestAccuracy = [0, 0]

# test regularization hyperparameters 0.00, 0.01, ..., 0.20
for i in range(25):
    rp = i/100
    
    # build the QDA classifier
    model = QuadraticDiscriminantAnalysis(reg_param = rp)

    # fit the QDA classifier to the training data
    model.fit(trainX, trainY)
    
    # find the mean cross-validation accuracy
    mean_cv_scores = np.mean(cross_val_score(model, trainX, trainY, cv = 5))

    # print quality metrics
    print('Mean CV accuracy for regularization parameter', rp, 'is', mean_cv_scores)
    
    # save the hyperparameter reg_param if better than found before
    if mean_cv_scores > bestAccuracy[0]:
        bestAccuracy = [mean_cv_scores, rp]
        
print('\nThe best dev accuracy', bestAccuracy[0], 'occured with', bestAccuracy[1], 'regularization parameter')
        
# build the QDA classifier
model = QuadraticDiscriminantAnalysis(reg_param = bestAccuracy[1])

# fit the QDA classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTest Classification Report for', bestAccuracy[0], 'reg_param:\n\n', classification_report(testY, predictedY))
print('\nConfusion Matrix:\n')
sn.heatmap(confusion_matrix(testY, predictedY), annot = True)
# Out:
# Mean CV accuracy for regularization parameter 0.0 is 0.8533333333333333
# Mean CV accuracy for regularization parameter 0.01 is 0.8542222222222222
# Mean CV accuracy for regularization parameter 0.02 is 0.8533333333333333
# Mean CV accuracy for regularization parameter 0.03 is 0.8533333333333333
# Mean CV accuracy for regularization parameter 0.04 is 0.8533333333333333
# Mean CV accuracy for regularization parameter 0.05 is 0.8533333333333333
# Mean CV accuracy for regularization parameter 0.06 is 0.8533333333333333
# Mean CV accuracy for regularization parameter 0.07 is 0.8542222222222222
# Mean CV accuracy for regularization parameter 0.08 is 0.8560000000000001
# Mean CV accuracy for regularization parameter 0.09 is 0.8560000000000001
# Mean CV accuracy for regularization parameter 0.1 is 0.8560000000000001
# Mean CV accuracy for regularization parameter 0.11 is 0.8568888888888889
# Mean CV accuracy for regularization parameter 0.12 is 0.8568888888888889
# Mean CV accuracy for regularization parameter 0.13 is 0.8568888888888889
# Mean CV accuracy for regularization parameter 0.14 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.15 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.16 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.17 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.18 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.19 is 0.8595555555555554
# Mean CV accuracy for regularization parameter 0.2 is 0.8586666666666666
# Mean CV accuracy for regularization parameter 0.21 is 0.8586666666666666
# Mean CV accuracy for regularization parameter 0.22 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.23 is 0.8577777777777778
# Mean CV accuracy for regularization parameter 0.24 is 0.8577777777777778
#
# The best dev accuracy 0.8595555555555554 occured with 0.19 regularization parameter
#
# Test Classification Report for 0.8595555555555554 reg_param:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       120
#            1       0.91      0.83      0.87       127
#            2       0.95      0.95      0.95       128
#
#     accuracy                           0.88       375
#    macro avg       0.88      0.88      0.88       375
# weighted avg       0.89      0.88      0.88       375
#
#
# Confusion Matrix:

# %% [markdown]
# ### Example from scikit-learn: LDA vs QDA
#
# This example is lightly modified from the [scikit-learn documentation](https://scikit-learn.org/stable/auto_examples/classification/plot_lda_qda.html#sphx-glr-auto-examples-classification-plot-lda-qda-py).

# %%
from scipy import linalg
import matplotlib as mpl
from matplotlib import colors

# Colormap
cmap = colors.LinearSegmentedColormap(
    'red_blue_classes',
    {'red': [(0, 1, 1), (1, 0.7, 0.7)],
     'green': [(0, 0.7, 0.7), (1, 0.7, 0.7)],
     'blue': [(0, 0.7, 0.7), (1, 1, 1)]})
plt.cm.register_cmap(cmap=cmap)

# Generate datasets
def dataset_fixed_cov():
    # Generate 2 Gaussians samples with the same covariance matrix
    n, dim = 300, 2
    np.random.seed(0)
    C = np.array([[0., -0.23], [0.83, .23]])
    X = np.r_[np.dot(np.random.randn(n, dim), C), np.dot(np.random.randn(n, dim), C) + np.array([1, 1])]
    y = np.hstack((np.zeros(n), np.ones(n)))
    return X, y

def dataset_cov():
    # Generate 2 Gaussians samples with different covariance matrices
    n, dim = 300, 2
    np.random.seed(0)
    C = np.array([[0., -1.], [2.5, .7]]) * 2.
    X = np.r_[np.dot(np.random.randn(n, dim), C), np.dot(np.random.randn(n, dim), C.T) + np.array([1, 4])]
    y = np.hstack((np.zeros(n), np.ones(n)))
    return X, y

# Plot functions
def plot_data(lda, X, y, y_pred, fig_index):
    splot = plt.subplot(2, 2, fig_index)
    if fig_index == 1:
        plt.title('Linear Discriminant Analysis')
        plt.ylabel('Data with\n fixed covariance')
    elif fig_index == 2:
        plt.title('Quadratic Discriminant Analysis')
    elif fig_index == 3:
        plt.ylabel('Data with\n varying covariances')

    tp = (y == y_pred)  # True Positive
    tp0, tp1 = tp[y == 0], tp[y == 1]
    X0, X1 = X[y == 0], X[y == 1]
    X0_tp, X0_fp = X0[tp0], X0[~tp0]
    X1_tp, X1_fp = X1[tp1], X1[~tp1]

    # class 0: dots
    plt.scatter(X0_tp[:, 0], X0_tp[:, 1], marker='.', color='red')
    plt.scatter(X0_fp[:, 0], X0_fp[:, 1], marker='x', s=20, color='#990000')  # dark red

    # class 1: dots
    plt.scatter(X1_tp[:, 0], X1_tp[:, 1], marker='.', color='blue')
    plt.scatter(X1_fp[:, 0], X1_fp[:, 1], marker='x', s=20, color='#000099')  # dark blue

    # class 0 and 1 : areas
    x_min, x_max = plt.xlim()
    y_min, y_max = plt.ylim()
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 100))
    
    Z = lda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
    Z = Z[:, 1].reshape(xx.shape)
    
    plt.pcolormesh(xx, yy, Z, cmap='red_blue_classes', norm=colors.Normalize(0., 1.), zorder=0, shading='auto')
    plt.contour(xx, yy, Z, [0.5], linewidths=2., colors='white')

    return splot

plt.figure(figsize=(10, 8), facecolor='white')
plt.suptitle('Linear Discriminant Analysis vs Quadratic Discriminant Analysis', y=0.98, fontsize=15)

for i, (X, y) in enumerate([dataset_fixed_cov(), dataset_cov()]):
    # Linear Discriminant Analysis
    lda = LinearDiscriminantAnalysis()
    y_pred = lda.fit(X, y).predict(X)
    splot = plot_data(lda, X, y, y_pred, fig_index=2 * i + 1)

    # Quadratic Discriminant Analysis
    qda = QuadraticDiscriminantAnalysis()
    y_pred = qda.fit(X, y).predict(X)
    splot = plot_data(qda, X, y, y_pred, fig_index=2 * i + 2)

# %% [markdown]
# ### Example: Breast Cancer

# %%
# import the breast cancer dataset
breastcancer = datasets.load_breast_cancer()

# find the data and labels
X = breastcancer.data
Y = breastcancer.target

# split the data into train and test sets
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.25)

# build the classifier
model = DA()

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nClassification Report:\n\n', classification_report(testY, predictedY))
print('\nConfusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY), annot = True)
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        57
#            1       0.91      1.00      0.96        86
#
#     accuracy                           0.94       143
#    macro avg       0.96      0.93      0.94       143
# weighted avg       0.95      0.94      0.94       143
#
#
# Confusion Matrix:

# %% [markdown]
# ### Example: Classifying MNIST Handwritten Digits with LDA and QDA
#
# #### LDA

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = LinearDiscriminantAnalysis()

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      5923
#            1       0.87      0.96      0.91      6742
#            2       0.92      0.82      0.86      5958
#            3       0.86      0.85      0.86      6131
#            4       0.86      0.90      0.88      5842
#            5       0.83      0.82      0.83      5421
#            6       0.93      0.92      0.92      5918
#            7       0.92      0.84      0.88      6265
#            8       0.81      0.80      0.80      5851
#            9       0.78      0.86      0.82      5949
#
#     accuracy                           0.87     60000
#    macro avg       0.87      0.87      0.87     60000
# weighted avg       0.87      0.87      0.87     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       980
#            1       0.89      0.97      0.93      1135
#            2       0.92      0.79      0.85      1032
#            3       0.87      0.87      0.87      1010
#            4       0.84      0.90      0.87       982
#            5       0.84      0.82      0.83       892
#            6       0.91      0.89      0.90       958
#            7       0.91      0.84      0.88      1028
#            8       0.80      0.81      0.80       974
#            9       0.81      0.85      0.83      1009
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# #### LDA with Ledoit-Wolf shrinkage

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = LinearDiscriminantAnalysis(solver='lsqr', shrinkage='auto')

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      5923
#            1       0.87      0.96      0.91      6742
#            2       0.92      0.82      0.87      5958
#            3       0.86      0.84      0.85      6131
#            4       0.87      0.90      0.88      5842
#            5       0.84      0.83      0.83      5421
#            6       0.93      0.92      0.93      5918
#            7       0.93      0.85      0.89      6265
#            8       0.81      0.80      0.81      5851
#            9       0.79      0.88      0.83      5949
#
#     accuracy                           0.88     60000
#    macro avg       0.88      0.87      0.87     60000
# weighted avg       0.88      0.88      0.88     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       980
#            1       0.89      0.96      0.93      1135
#            2       0.92      0.81      0.86      1032
#            3       0.87      0.88      0.87      1010
#            4       0.86      0.91      0.88       982
#            5       0.85      0.81      0.83       892
#            6       0.91      0.91      0.91       958
#            7       0.92      0.84      0.88      1028
#            8       0.81      0.81      0.81       974
#            9       0.82      0.88      0.85      1009
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# #### QDA

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = QuadraticDiscriminantAnalysis()

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\sklearn\discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.36      0.99      0.53      5923
#            1       0.87      0.95      0.91      6742
#            2       0.95      0.22      0.36      5958
#            3       0.69      0.29      0.41      6131
#            4       0.95      0.11      0.20      5842
#            5       0.96      0.08      0.14      5421
#            6       0.74      0.97      0.84      5918
#            7       0.95      0.35      0.52      6265
#            8       0.47      0.67      0.55      5851
#            9       0.44      0.97      0.61      5949
#
#     accuracy                           0.57     60000
#    macro avg       0.74      0.56      0.51     60000
# weighted avg       0.74      0.57      0.52     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.34      0.97      0.50       980
#            1       0.91      0.95      0.93      1135
#            2       0.90      0.18      0.30      1032
#            3       0.64      0.26      0.37      1010
#            4       0.92      0.09      0.16       982
#            5       0.77      0.05      0.09       892
#            6       0.73      0.96      0.83       958
#            7       0.89      0.29      0.44      1028
#            8       0.45      0.65      0.53       974
#            9       0.42      0.95      0.59      1009
#
#     accuracy                           0.54     10000
#    macro avg       0.70      0.53      0.47     10000
# weighted avg       0.70      0.54      0.48     10000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# #### QDA with Regularization

# %%
# collinearity warnings keep popping up, so we suppress them
import warnings
warnings.filterwarnings('ignore')

# import MNIST data
(trainX, trainY), (testX, testY) = mnist.load_data()

# reshape the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])

# normalize coordinates
trainX = trainX.astype('float')/255.0
testX = testX.astype('float')/255.0

# initialize accuracy and hyperparameter list
bestAccuracy = [0, 0]

# test regularization hyperparameters 0.00, 0.01, ..., 0.19
for i in range(20):
    rp = i/100
    
    # build the QDA classifier
    model = QuadraticDiscriminantAnalysis(reg_param = rp)

    # fit the QDA classifier to the training data
    model.fit(trainX, trainY)
    
    # find the mean cross-validation accuracy
    mean_cv_scores = np.mean(cross_val_score(model, trainX, trainY, cv = 5))

    # print quality metrics
    print('Mean CV accuracy for regularization parameter', rp, 'is', mean_cv_scores)
    
    # save the hyperparameter reg_param if better than found before
    if mean_cv_scores > bestAccuracy[0]:
        bestAccuracy = [mean_cv_scores, rp]
        
print('\nThe best dev accuracy', bestAccuracy[0], 'occured with', bestAccuracy[1], 'regularization parameter')
        
# build the QDA classifier
model = QuadraticDiscriminantAnalysis(reg_param = bestAccuracy[1])

# fit the QDA classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTest Classification Report for', bestAccuracy[1], 'reg_param:\n\n', classification_report(testY, predictedY))

print('\nTest Confusion Matrix:\n')
sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# Mean CV accuracy for regularization parameter 0.0 is 0.5438166666666666
# Mean CV accuracy for regularization parameter 0.01 is 0.9422333333333335
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-cd343d914128> in <module>
#      28
#      29     # find the mean cross-validation accuracy
# ---> 30     mean_cv_scores = np.mean(cross_val_score(model, trainX, trainY, cv = 5))
#      31
#      32     # print quality metrics
#
# ~\anaconda3\envs\DL\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\envs\DL\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     404                                 fit_params=fit_params,
#     405                                 pre_dispatch=pre_dispatch,
# --> 406                                 error_score=error_score)
#     407     return cv_results['test_score']
#     408
#
# ~\anaconda3\envs\DL\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\envs\DL\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     246             return_times=True, return_estimator=return_estimator,
#     247             error_score=error_score)
# --> 248         for train, test in cv.split(X, y, groups))
#     249
#     250     zipped_scores = list(zip(*scores))
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\DL\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\DL\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~\anaconda3\envs\DL\lib\site-packages\sklearn\discriminant_analysis.py in fit(self, X, y)
#     710             Xgc = Xg - meang
#     711             # Xgc = U * S * V.T
# --> 712             _, S, Vt = np.linalg.svd(Xgc, full_matrices=False)
#     713             rank = np.sum(S > self.tol)
#     714             if rank < n_features:
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1659
#    1660         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1661         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1662         u = u.astype(result_t, copy=False)
#    1663         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %% [markdown]
# We now find 96% accuracy! This is easily the best result we have found for MNIST in the class so far.

# %% [markdown]
# ## Lecture 21 - Principal Components Analysis
#
# The classification methods we have used are quite good at some tasks, such as identifying handwritten digits from the MNIST dataset. Harder problems, like classifying images from the CIFAR-10 dataset, are still a challenge, and are very computationally intensive due to the high dimension data. The next topic in the class will be to try to manage this dimensionality problem.

# %% [markdown]
# ### Principal Components Analysis (PCA)
#
# Principal components analysis (PCA) is a method for reducing the dimension of the data by using some ideas from linear algebra to map the rows from a data matrix $X$ from its default $d$-dimensional space to an $r$-dimensional space for some $r < d$.
#
# Please see the notes in class for the math that makes this work, but the code is below.

# %%
# Principal component analysis
def PCA(D, alpha):        
    # find the original dimension and print it
    dimension = D.shape[1]
    print('The original dimension of the data is', dimension)
    
    # center D to have mean 0
    D -= np.mean(D, axis=0)
    
    # compute the covariance matrix
    Sigma = (1/D.shape[0]) * D.T @ D

    # compute the eigenvalues and eigenvectors of D^T D
    (eValues, eVectors) = np.linalg.eigh(Sigma)

    # compute the total variance
    varD = np.sum(eValues)
    
    # initialize the variance for A to 0
    varA = 0.0
    
    # reverse eValues and eVectors
    eValues = np.flip(eValues)
    eVectors = np.flip(eVectors, axis=1)

    # find the minimum dimension consisting of fraction at least alpha of the total variance
    for r in np.arange(0, eValues.shape[0]):
        varA += eValues[r]
        ratio = varA/varD

        if ratio > alpha:
            dimension = r + 1
            print('The new dimension of the data is', dimension, 'and it explains', ratio, 'of the variance')
            break
            
    # construct the new basis
    basis = eVectors[:,:dimension]
    
    # create the datapoints in the new space
    A = D @ basis
    
    # return points
    return A

# %% [markdown]
# To test this out a bit, let's bring in our neural network code and our favorite dataset (MNIST), use PCA to reduce the dimension of MNIST, and then train the neural net to classify the lower-dimensional data.

# %% [markdown]
# First, let's run it on MNIST images and compute the time. Later, we will compare it to using PCA and training the net on the resulting data.

# %%
# import MNIST data
(trainX, trainY), (testX, testY) = mnist.load_data()

# reshape the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])

# normalize coordinates
trainX = trainX.astype('float')/255.0
testX = testX.astype('float')/255.0

# fit the model to the training data
print('Now training QDA...')

start = time.time()

model = QuadraticDiscriminantAnalysis(reg_param = 0.05)
model.fit(trainX, trainY)

end = time.time()

print('QDA training is finished after', end - start, 'seconds')

# predict the labels of the test set
print('Now testing QDA...')

start = time.time()

predictedY = model.predict(testX)

end = time.time()

print('QDA prediction is finished after', end - start, 'seconds')

# print quality metrics
print('\nTest Classification Report for reg_param =', 0.05, classification_report(testY, predictedY))

print('\nTest Confusion Matrix:\n')
sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# Now training QDA...

# %% [markdown]
# We achieved 98% accuracy on the validation set and the run time was 46 seconds. Now, let's do exactly the same thing *except* we will use PCA to reduce the dimension of the same data before running the neural network.

# %%
# import MNIST data
(trainX, trainY), (testX, testY) = mnist.load_data()

# reshape the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])

# normalize coordinates
trainX = trainX.astype('float')/255.0
testX = testX.astype('float')/255.0

# Use PCA
print('Now using PCA dimensionality reduction...')

start = time.time()

# Apply PCA to the data matrices
trainX = PCA(trainX, 0.8)
testX = PCA(testX, 0.8)

end = time.time()

print('PCA finished in', end - start, 'seconds')

# fit the model to the training data
print('Now training QDA...')

start = time.time()

model = QuadraticDiscriminantAnalysis(reg_param = 0.05)
model.fit(trainX, trainY)

end = time.time()

print('QDA training is finished after', end - start, 'seconds')

# predict the labels of the test set
print('Now testing QDA...')

start = time.time()

predictedY = model.predict(testX)

end = time.time()

print('QDA prediction is finished after', end - start, 'seconds')

# print quality metrics
print('\nTest Classification Report for reg_param =', 0.05, classification_report(testY, predictedY))

print('\nTest Confusion Matrix:\n')
sn.heatmap(confusion_matrix(testY, predictedY))
# Out:
# [INFO] Now running principal components analysis (PCA)
# [INFO] The original dimension of the data is 784
# [INFO] The new dimension of the data is 44 and it explains 0.80329075538368 of the variance
# [INFO] PCA finished in 3.970233201980591 seconds
# [INFO] Now training the neural network
# [INFO] Epoch = 1 of 25
# [INFO] Epoch = 2 of 25
# [INFO] Epoch = 3 of 25
# [INFO] Epoch = 4 of 25
# [INFO] Epoch = 5 of 25
# [INFO] Epoch = 6 of 25
# [INFO] Epoch = 7 of 25
# [INFO] Epoch = 8 of 25
# [INFO] Epoch = 9 of 25
# [INFO] Epoch = 10 of 25
# [INFO] Epoch = 11 of 25
# [INFO] Epoch = 12 of 25
# [INFO] Epoch = 13 of 25
# [INFO] Epoch = 14 of 25
# [INFO] Epoch = 15 of 25
# [INFO] Epoch = 16 of 25
# [INFO] Epoch = 17 of 25
# [INFO] Epoch = 18 of 25
# [INFO] Epoch = 19 of 25
# [INFO] Epoch = 20 of 25
# [INFO] Epoch = 21 of 25
# [INFO] Epoch = 22 of 25
# [INFO] Epoch = 23 of 25
# [INFO] Epoch = 24 of 25
# [INFO] Epoch = 25 of 25
# [INFO] Neural network training is finished after 6.0101847648620605 seconds
# [INFO] Training set accuracy is 0.9903777777777778
# [INFO] Validation set accuracy is 0.9810666666666666

# %% [markdown]
# Here, requiring a number of dimensions explaining 80\% of the variance of the dataset with PCA reduced the dimension from 784 to 44, a reduction of over 94\%! What is even more amazing is that the training accuracy on the lower-dimensional data is still 98\%, but the time for PCA (4 seconds) + the time of training (6 seconds) is only 10 seconds, about 1/4 the time as without PCA.

# %% [markdown]
# Let's try it with CIFAR-10, since it was pretty intractable with a fully-connected feedforward neural network, so let's see if performance improves or at least stays the same when we use PCA.
#
# First, without PCA.

# %%
cifarData = cifar10.load_data()

numberOfImages = 50000

# The datapoints are in mnistData[0][0]
X = cifarData[0][0][:numberOfImages].reshape([numberOfImages,32*32*3]).astype('float')

# Normalize the data
X = X/255.0

# The labels are in mnistData[0][1]
Y = cifarData[0][1][:numberOfImages]

# randomly choose 75% of the data to be the training set and 25% for the validation set
(trainX, valX, trainY, valY) = train_test_split(X, Y, test_size = 0.25)

start = time.time()

# fit the model to the training data
print('[INFO] Now training the neural network')

#model = FeedforwardNeuralNetwork([X.shape[1], 128, 10], 0.001, ['exp', 0.1], 20.0, 300.0, 64, 0.9,
#                                 ['Glorot', 'uniform'], 'ReLU', 'cross-entropy')

model = FeedforwardNeuralNetwork([X.shape[1], 64, 32, 16, 10], 0.001, 'none', 0.0, 0.0, 32, 0.0,
                                 ['Glorot', 'uniform'], 'ReLU', 'cross-entropy')

model.fit(trainX, trainY, valX, valY, 100, 1)

end = time.time()

print('[INFO] Neural network training is finished after', end - start, 'seconds')

# Compute the outputs and measure the accuracy on the train and validation sets
trainY = LabelBinarizer().fit_transform(trainY)
predictedY = model.predict(trainX)
predictedY = predictedY.argmax(axis=1)
trainY = trainY.argmax(axis=1)
print('[INFO] Training set accuracy is', accuracy_score(trainY, predictedY))

valY = LabelBinarizer().fit_transform(valY)
predictedY = model.predict(valX)
predictedY = predictedY.argmax(axis=1)
valY = valY.argmax(axis=1)
print('[INFO] Validation set accuracy is', accuracy_score(valY, predictedY))
# Out:
# [INFO] Now training the neural network
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:348: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:348: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [INFO] epoch = 1, loss = inf, training accuracy = 0.226987, validation accuracy = 0.227760
# [INFO] epoch = 2, loss = inf, training accuracy = 0.255093, validation accuracy = 0.252720
# [INFO] epoch = 3, loss = inf, training accuracy = 0.305200, validation accuracy = 0.300960
# [INFO] epoch = 4, loss = inf, training accuracy = 0.308267, validation accuracy = 0.309360
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:348: RuntimeWarning: invalid value encountered in log
# [INFO] epoch = 5, loss = inf, training accuracy = 0.322053, validation accuracy = 0.323840
# [INFO] epoch = 6, loss = inf, training accuracy = 0.338027, validation accuracy = 0.333840
# [INFO] epoch = 7, loss = inf, training accuracy = 0.326027, validation accuracy = 0.327760
# [INFO] epoch = 8, loss = inf, training accuracy = 0.335973, validation accuracy = 0.333120
# [INFO] epoch = 9, loss = inf, training accuracy = 0.336453, validation accuracy = 0.333520
# [INFO] epoch = 10, loss = inf, training accuracy = 0.356187, validation accuracy = 0.354400
# [INFO] epoch = 11, loss = inf, training accuracy = 0.359200, validation accuracy = 0.354000
# [INFO] epoch = 12, loss = inf, training accuracy = 0.366827, validation accuracy = 0.358720
# [INFO] epoch = 13, loss = inf, training accuracy = 0.373413, validation accuracy = 0.358080
# [INFO] epoch = 14, loss = inf, training accuracy = 0.382667, validation accuracy = 0.368400
# [INFO] epoch = 15, loss = inf, training accuracy = 0.382907, validation accuracy = 0.360480
# [INFO] epoch = 16, loss = inf, training accuracy = 0.380427, validation accuracy = 0.366640
# [INFO] epoch = 17, loss = inf, training accuracy = 0.377520, validation accuracy = 0.363680
# [INFO] epoch = 18, loss = inf, training accuracy = 0.392613, validation accuracy = 0.370240
# [INFO] epoch = 19, loss = inf, training accuracy = 0.415013, validation accuracy = 0.385280
# [INFO] epoch = 20, loss = inf, training accuracy = 0.411840, validation accuracy = 0.386240
# [INFO] epoch = 21, loss = inf, training accuracy = 0.424107, validation accuracy = 0.398320
# [INFO] epoch = 22, loss = inf, training accuracy = 0.415840, validation accuracy = 0.394320
# [INFO] epoch = 23, loss = inf, training accuracy = 0.427200, validation accuracy = 0.397440
# [INFO] epoch = 24, loss = inf, training accuracy = 0.431467, validation accuracy = 0.401600
# [INFO] epoch = 25, loss = inf, training accuracy = 0.424213, validation accuracy = 0.392880
# [INFO] epoch = 26, loss = inf, training accuracy = 0.441360, validation accuracy = 0.404160
# [INFO] epoch = 27, loss = inf, training accuracy = 0.438800, validation accuracy = 0.410000
# [INFO] epoch = 28, loss = inf, training accuracy = 0.444107, validation accuracy = 0.413920
# [INFO] epoch = 29, loss = inf, training accuracy = 0.456933, validation accuracy = 0.427040
# [INFO] epoch = 30, loss = inf, training accuracy = 0.455333, validation accuracy = 0.421280
# [INFO] epoch = 31, loss = inf, training accuracy = 0.437227, validation accuracy = 0.404480
# [INFO] epoch = 32, loss = inf, training accuracy = 0.457573, validation accuracy = 0.422240
# [INFO] epoch = 33, loss = inf, training accuracy = 0.451973, validation accuracy = 0.419360
# [INFO] epoch = 34, loss = inf, training accuracy = 0.470693, validation accuracy = 0.430800
# [INFO] epoch = 35, loss = inf, training accuracy = 0.476987, validation accuracy = 0.435840
# [INFO] epoch = 36, loss = inf, training accuracy = 0.463733, validation accuracy = 0.423840
# [INFO] epoch = 37, loss = inf, training accuracy = 0.477707, validation accuracy = 0.430000
# [INFO] epoch = 38, loss = inf, training accuracy = 0.459787, validation accuracy = 0.425680
# [INFO] epoch = 39, loss = inf, training accuracy = 0.482400, validation accuracy = 0.438080
# [INFO] epoch = 40, loss = inf, training accuracy = 0.474587, validation accuracy = 0.426560
# [INFO] epoch = 41, loss = inf, training accuracy = 0.479947, validation accuracy = 0.429200
# [INFO] epoch = 42, loss = inf, training accuracy = 0.492587, validation accuracy = 0.444000
# [INFO] epoch = 43, loss = inf, training accuracy = 0.492533, validation accuracy = 0.440960
# [INFO] epoch = 44, loss = inf, training accuracy = 0.469067, validation accuracy = 0.426880
# [INFO] epoch = 45, loss = inf, training accuracy = 0.488133, validation accuracy = 0.440320
# [INFO] epoch = 46, loss = inf, training accuracy = 0.500800, validation accuracy = 0.448480
# [INFO] epoch = 47, loss = inf, training accuracy = 0.494853, validation accuracy = 0.441760
# [INFO] epoch = 48, loss = inf, training accuracy = 0.505467, validation accuracy = 0.448080
# [INFO] epoch = 49, loss = inf, training accuracy = 0.502933, validation accuracy = 0.447280
# [INFO] epoch = 50, loss = inf, training accuracy = 0.495893, validation accuracy = 0.444400
# [INFO] epoch = 51, loss = inf, training accuracy = 0.495920, validation accuracy = 0.437040
# [INFO] epoch = 52, loss = inf, training accuracy = 0.495120, validation accuracy = 0.436480
# [INFO] epoch = 53, loss = inf, training accuracy = 0.493467, validation accuracy = 0.437120
# [INFO] epoch = 54, loss = inf, training accuracy = 0.487973, validation accuracy = 0.428640
# [INFO] epoch = 55, loss = inf, training accuracy = 0.512880, validation accuracy = 0.449920
# [INFO] epoch = 56, loss = inf, training accuracy = 0.479973, validation accuracy = 0.424000
# [INFO] epoch = 57, loss = inf, training accuracy = 0.507893, validation accuracy = 0.445040
# [INFO] epoch = 58, loss = inf, training accuracy = 0.508800, validation accuracy = 0.445920
# [INFO] epoch = 59, loss = inf, training accuracy = 0.503600, validation accuracy = 0.445440
# [INFO] epoch = 60, loss = inf, training accuracy = 0.498107, validation accuracy = 0.437680
# [INFO] epoch = 61, loss = inf, training accuracy = 0.510027, validation accuracy = 0.442560
# [INFO] epoch = 62, loss = inf, training accuracy = 0.508640, validation accuracy = 0.442720
# [INFO] epoch = 63, loss = inf, training accuracy = 0.517840, validation accuracy = 0.448880
# [INFO] epoch = 64, loss = inf, training accuracy = 0.513707, validation accuracy = 0.445040
# [INFO] epoch = 65, loss = inf, training accuracy = 0.522293, validation accuracy = 0.449920
# [INFO] epoch = 66, loss = inf, training accuracy = 0.519280, validation accuracy = 0.450480
# [INFO] epoch = 67, loss = inf, training accuracy = 0.520133, validation accuracy = 0.447120
# [INFO] epoch = 68, loss = inf, training accuracy = 0.534800, validation accuracy = 0.453840
# [INFO] epoch = 69, loss = inf, training accuracy = 0.521360, validation accuracy = 0.445760
# [INFO] epoch = 70, loss = inf, training accuracy = 0.510747, validation accuracy = 0.442240
# [INFO] epoch = 71, loss = inf, training accuracy = 0.523493, validation accuracy = 0.447920
# [INFO] epoch = 72, loss = inf, training accuracy = 0.529333, validation accuracy = 0.452320
# [INFO] epoch = 73, loss = inf, training accuracy = 0.531813, validation accuracy = 0.453520
# [INFO] epoch = 74, loss = inf, training accuracy = 0.532827, validation accuracy = 0.450400
# [INFO] epoch = 75, loss = inf, training accuracy = 0.531573, validation accuracy = 0.445200
# [INFO] epoch = 76, loss = inf, training accuracy = 0.529680, validation accuracy = 0.444720
# [INFO] epoch = 77, loss = inf, training accuracy = 0.530613, validation accuracy = 0.448960
# [INFO] epoch = 78, loss = inf, training accuracy = 0.540133, validation accuracy = 0.452400
# [INFO] epoch = 79, loss = inf, training accuracy = 0.522827, validation accuracy = 0.443200
# [INFO] epoch = 80, loss = inf, training accuracy = 0.545333, validation accuracy = 0.456400
# [INFO] epoch = 81, loss = inf, training accuracy = 0.535120, validation accuracy = 0.451600
# [INFO] epoch = 82, loss = inf, training accuracy = 0.553787, validation accuracy = 0.455760
# [INFO] epoch = 83, loss = inf, training accuracy = 0.547973, validation accuracy = 0.456640
# [INFO] epoch = 84, loss = inf, training accuracy = 0.518267, validation accuracy = 0.436160
# [INFO] epoch = 85, loss = inf, training accuracy = 0.551653, validation accuracy = 0.456560
# [INFO] epoch = 86, loss = inf, training accuracy = 0.550720, validation accuracy = 0.460560
# [INFO] epoch = 87, loss = inf, training accuracy = 0.552667, validation accuracy = 0.460240
# [INFO] epoch = 88, loss = inf, training accuracy = 0.553707, validation accuracy = 0.459520
# [INFO] epoch = 89, loss = inf, training accuracy = 0.552960, validation accuracy = 0.452480
# [INFO] epoch = 90, loss = inf, training accuracy = 0.548720, validation accuracy = 0.452880
# [INFO] epoch = 91, loss = inf, training accuracy = 0.550880, validation accuracy = 0.453360
# [INFO] epoch = 92, loss = inf, training accuracy = 0.548587, validation accuracy = 0.445360
# [INFO] epoch = 93, loss = inf, training accuracy = 0.539307, validation accuracy = 0.445760
# [INFO] epoch = 94, loss = inf, training accuracy = 0.561893, validation accuracy = 0.458400
# [INFO] epoch = 95, loss = inf, training accuracy = 0.549973, validation accuracy = 0.452480
# [INFO] epoch = 96, loss = inf, training accuracy = 0.572480, validation accuracy = 0.460560
# [INFO] epoch = 97, loss = inf, training accuracy = 0.558667, validation accuracy = 0.456800
# [INFO] epoch = 98, loss = inf, training accuracy = 0.575227, validation accuracy = 0.465280
# [INFO] epoch = 99, loss = inf, training accuracy = 0.561200, validation accuracy = 0.449680
# [INFO] epoch = 100, loss = inf, training accuracy = 0.573680, validation accuracy = 0.461760
# [INFO] Neural network training is finished after 1551.836727142334 seconds
# [INFO] Training set accuracy is 0.57368
# [INFO] Validation set accuracy is 0.46176

# %% [markdown]
# Next, let's use PCA to shrink the data to a lower dimension and see how the runtime and performance compare with all settings equal.

# %%
## cifarData = cifar10.load_data()

numberOfImages = 50000

# The datapoints are in mnistData[0][0]
X = cifarData[0][0][:numberOfImages].reshape([numberOfImages,32*32*3]).astype('float')

start = time.time()

# Apply PCA to the data matrix X
X = PCA(X, 0.9)

end = time.time()

print('[INFO] PCA finished in', end - start, 'seconds')

# Normalize the data
X = X/255.0

# The labels are in mnistData[0][1]
Y = cifarData[0][1][:numberOfImages]

# randomly choose 75% of the data to be the training set and 25% for the validation set
(trainX, valX, trainY, valY) = train_test_split(X, Y, test_size = 0.25)

start = time.time()

# fit the model to the training data
print('[INFO] Now training the neural network')

#model = FeedforwardNeuralNetwork([X.shape[1], 128, 10], 0.001, ['exp', 0.1], 20.0, 300.0, 64, 0.9,
#                                 ['Glorot', 'uniform'], 'ReLU', 'cross-entropy')

model = FeedforwardNeuralNetwork([X.shape[1], 64, 32, 16, 10], 0.001, 'none', 0.0, 0.0, 32, 0.0,
                                 ['Glorot', 'uniform'], 'ReLU', 'cross-entropy')

model.fit(trainX, trainY, valX, valY, 100, 1)

end = time.time()

print('[INFO] Neural network training is finished after', end - start, 'seconds')

# Compute the outputs and measure the accuracy on the train and validation sets
trainY = LabelBinarizer().fit_transform(trainY)
predictedY = model.predict(trainX)
predictedY = predictedY.argmax(axis=1)
trainY = trainY.argmax(axis=1)
print('[INFO] Training set accuracy is', accuracy_score(trainY, predictedY))

valY = LabelBinarizer().fit_transform(valY)
predictedY = model.predict(valX)
predictedY = predictedY.argmax(axis=1)
valY = valY.argmax(axis=1)
print('[INFO] Validation set accuracy is', accuracy_score(valY, predictedY))
# Out:
# [INFO] Now running principal components analysis (PCA)
# [INFO] The original dimension of the data is 3072
# [INFO] The new dimension of the data is 99 and it explains 0.9003187633153611 of the variance
# [INFO] PCA finished in 156.3903968334198 seconds
# [INFO] Now training the neural network
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:348: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:348: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:348: RuntimeWarning: invalid value encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [INFO] epoch = 1, loss = inf, training accuracy = 0.274720, validation accuracy = 0.275280
# [INFO] epoch = 2, loss = inf, training accuracy = 0.311893, validation accuracy = 0.309680
# [INFO] epoch = 3, loss = inf, training accuracy = 0.338987, validation accuracy = 0.331760
# [INFO] epoch = 4, loss = inf, training accuracy = 0.357520, validation accuracy = 0.345280
# [INFO] epoch = 5, loss = inf, training accuracy = 0.376400, validation accuracy = 0.362640
# [INFO] epoch = 6, loss = inf, training accuracy = 0.391680, validation accuracy = 0.375520
# [INFO] epoch = 7, loss = inf, training accuracy = 0.406347, validation accuracy = 0.389280
# [INFO] epoch = 8, loss = inf, training accuracy = 0.415200, validation accuracy = 0.398640
# [INFO] epoch = 9, loss = inf, training accuracy = 0.419680, validation accuracy = 0.397680
# [INFO] epoch = 10, loss = inf, training accuracy = 0.430160, validation accuracy = 0.408400
# [INFO] epoch = 11, loss = inf, training accuracy = 0.436613, validation accuracy = 0.416000
# [INFO] epoch = 12, loss = inf, training accuracy = 0.440507, validation accuracy = 0.415680
# [INFO] epoch = 13, loss = inf, training accuracy = 0.445360, validation accuracy = 0.422080
# [INFO] epoch = 14, loss = inf, training accuracy = 0.453733, validation accuracy = 0.428640
# [INFO] epoch = 15, loss = inf, training accuracy = 0.457680, validation accuracy = 0.430240
# [INFO] epoch = 16, loss = inf, training accuracy = 0.456347, validation accuracy = 0.428000
# [INFO] epoch = 17, loss = inf, training accuracy = 0.462240, validation accuracy = 0.432960
# [INFO] epoch = 18, loss = inf, training accuracy = 0.468907, validation accuracy = 0.435280
# [INFO] epoch = 19, loss = inf, training accuracy = 0.467600, validation accuracy = 0.436000
# [INFO] epoch = 20, loss = inf, training accuracy = 0.479867, validation accuracy = 0.441520
# [INFO] epoch = 21, loss = inf, training accuracy = 0.481600, validation accuracy = 0.442080
# [INFO] epoch = 22, loss = inf, training accuracy = 0.486507, validation accuracy = 0.446640
# [INFO] epoch = 23, loss = inf, training accuracy = 0.488933, validation accuracy = 0.445520
# [INFO] epoch = 24, loss = inf, training accuracy = 0.489387, validation accuracy = 0.445440
# [INFO] epoch = 25, loss = inf, training accuracy = 0.492960, validation accuracy = 0.451120
# [INFO] epoch = 26, loss = inf, training accuracy = 0.497947, validation accuracy = 0.452000
# [INFO] epoch = 27, loss = inf, training accuracy = 0.502800, validation accuracy = 0.460080
# [INFO] epoch = 28, loss = inf, training accuracy = 0.506587, validation accuracy = 0.458800
# [INFO] epoch = 29, loss = inf, training accuracy = 0.505413, validation accuracy = 0.458640
# [INFO] epoch = 30, loss = inf, training accuracy = 0.511573, validation accuracy = 0.460000
# [INFO] epoch = 31, loss = inf, training accuracy = 0.511867, validation accuracy = 0.463120
# [INFO] epoch = 32, loss = inf, training accuracy = 0.515573, validation accuracy = 0.464960
# [INFO] epoch = 33, loss = inf, training accuracy = 0.516987, validation accuracy = 0.460320
# [INFO] epoch = 34, loss = inf, training accuracy = 0.519813, validation accuracy = 0.464800
# [INFO] epoch = 35, loss = inf, training accuracy = 0.523173, validation accuracy = 0.465520
# [INFO] epoch = 36, loss = inf, training accuracy = 0.524320, validation accuracy = 0.466080
# [INFO] epoch = 37, loss = inf, training accuracy = 0.527733, validation accuracy = 0.469440
# [INFO] epoch = 38, loss = inf, training accuracy = 0.529280, validation accuracy = 0.468320
# [INFO] epoch = 39, loss = inf, training accuracy = 0.528213, validation accuracy = 0.465440
# [INFO] epoch = 40, loss = inf, training accuracy = 0.533680, validation accuracy = 0.469920
# [INFO] epoch = 41, loss = inf, training accuracy = 0.535307, validation accuracy = 0.469200
# [INFO] epoch = 42, loss = inf, training accuracy = 0.539040, validation accuracy = 0.472880
# [INFO] epoch = 43, loss = inf, training accuracy = 0.539227, validation accuracy = 0.471440
# [INFO] epoch = 44, loss = inf, training accuracy = 0.541707, validation accuracy = 0.474880
# [INFO] epoch = 45, loss = inf, training accuracy = 0.547147, validation accuracy = 0.477120
# [INFO] epoch = 46, loss = inf, training accuracy = 0.542267, validation accuracy = 0.474880
# [INFO] epoch = 47, loss = inf, training accuracy = 0.546027, validation accuracy = 0.476880
# [INFO] epoch = 48, loss = inf, training accuracy = 0.547947, validation accuracy = 0.480320
# [INFO] epoch = 49, loss = inf, training accuracy = 0.548853, validation accuracy = 0.481040
# [INFO] epoch = 50, loss = inf, training accuracy = 0.552747, validation accuracy = 0.479280
# [INFO] epoch = 51, loss = inf, training accuracy = 0.548880, validation accuracy = 0.477520
# [INFO] epoch = 52, loss = inf, training accuracy = 0.554693, validation accuracy = 0.479760
# [INFO] epoch = 53, loss = inf, training accuracy = 0.557547, validation accuracy = 0.478800
# [INFO] epoch = 54, loss = inf, training accuracy = 0.554400, validation accuracy = 0.484080
# [INFO] epoch = 55, loss = inf, training accuracy = 0.558667, validation accuracy = 0.482560
# [INFO] epoch = 56, loss = inf, training accuracy = 0.559707, validation accuracy = 0.481760
# [INFO] epoch = 57, loss = inf, training accuracy = 0.558480, validation accuracy = 0.479040
# [INFO] epoch = 58, loss = inf, training accuracy = 0.558933, validation accuracy = 0.478320
# [INFO] epoch = 59, loss = inf, training accuracy = 0.564427, validation accuracy = 0.483040
# [INFO] epoch = 60, loss = inf, training accuracy = 0.563760, validation accuracy = 0.481920
# [INFO] epoch = 61, loss = inf, training accuracy = 0.561653, validation accuracy = 0.480480
# [INFO] epoch = 62, loss = inf, training accuracy = 0.568373, validation accuracy = 0.484720
# [INFO] epoch = 63, loss = inf, training accuracy = 0.566960, validation accuracy = 0.488240
# [INFO] epoch = 64, loss = inf, training accuracy = 0.567360, validation accuracy = 0.483920
# [INFO] epoch = 65, loss = inf, training accuracy = 0.570000, validation accuracy = 0.482880
# [INFO] epoch = 66, loss = inf, training accuracy = 0.573200, validation accuracy = 0.483760
# [INFO] epoch = 67, loss = inf, training accuracy = 0.567680, validation accuracy = 0.479120
# [INFO] epoch = 68, loss = inf, training accuracy = 0.573067, validation accuracy = 0.485040
# [INFO] epoch = 69, loss = inf, training accuracy = 0.567627, validation accuracy = 0.481440
# [INFO] epoch = 70, loss = inf, training accuracy = 0.574933, validation accuracy = 0.488400
# [INFO] epoch = 71, loss = inf, training accuracy = 0.579973, validation accuracy = 0.490560
# [INFO] epoch = 72, loss = inf, training accuracy = 0.581387, validation accuracy = 0.486560
# [INFO] epoch = 73, loss = inf, training accuracy = 0.581547, validation accuracy = 0.486720
# [INFO] epoch = 74, loss = inf, training accuracy = 0.584747, validation accuracy = 0.486880
# [INFO] epoch = 75, loss = inf, training accuracy = 0.581227, validation accuracy = 0.486160
# [INFO] epoch = 76, loss = inf, training accuracy = 0.581813, validation accuracy = 0.483760
# [INFO] epoch = 77, loss = inf, training accuracy = 0.582800, validation accuracy = 0.484640
# [INFO] epoch = 78, loss = inf, training accuracy = 0.581680, validation accuracy = 0.486800
# [INFO] epoch = 79, loss = inf, training accuracy = 0.586560, validation accuracy = 0.489200
# [INFO] epoch = 80, loss = inf, training accuracy = 0.586933, validation accuracy = 0.488320
# [INFO] epoch = 81, loss = inf, training accuracy = 0.583760, validation accuracy = 0.483680
# [INFO] epoch = 82, loss = inf, training accuracy = 0.582213, validation accuracy = 0.484160
# [INFO] epoch = 83, loss = inf, training accuracy = 0.586640, validation accuracy = 0.487680
# [INFO] epoch = 84, loss = inf, training accuracy = 0.589093, validation accuracy = 0.488480
# [INFO] epoch = 85, loss = inf, training accuracy = 0.592453, validation accuracy = 0.490480
# [INFO] epoch = 86, loss = inf, training accuracy = 0.592587, validation accuracy = 0.487920
# [INFO] epoch = 87, loss = inf, training accuracy = 0.591253, validation accuracy = 0.486800
# [INFO] epoch = 88, loss = inf, training accuracy = 0.590160, validation accuracy = 0.485360
# [INFO] epoch = 89, loss = inf, training accuracy = 0.597307, validation accuracy = 0.488960
# [INFO] epoch = 90, loss = inf, training accuracy = 0.594613, validation accuracy = 0.487920
# [INFO] epoch = 91, loss = inf, training accuracy = 0.597227, validation accuracy = 0.488320
# [INFO] epoch = 92, loss = inf, training accuracy = 0.598507, validation accuracy = 0.490000
# [INFO] epoch = 93, loss = inf, training accuracy = 0.593547, validation accuracy = 0.488640
# [INFO] epoch = 94, loss = inf, training accuracy = 0.592987, validation accuracy = 0.481440
# [INFO] epoch = 95, loss = inf, training accuracy = 0.601173, validation accuracy = 0.488640
# [INFO] epoch = 96, loss = inf, training accuracy = 0.596800, validation accuracy = 0.483360
# [INFO] epoch = 97, loss = inf, training accuracy = 0.598587, validation accuracy = 0.488400
# [INFO] epoch = 98, loss = inf, training accuracy = 0.600480, validation accuracy = 0.485600
# [INFO] epoch = 99, loss = inf, training accuracy = 0.601280, validation accuracy = 0.485920
# [INFO] epoch = 100, loss = inf, training accuracy = 0.599920, validation accuracy = 0.486960
# [INFO] Neural network training is finished after 76.77070140838623 seconds
# [INFO] Training set accuracy is 0.59992
# [INFO] Validation set accuracy is 0.48696

# %% [markdown]
# Performance is still not great, but it is better by 2.5% accuracy on the validation set. This is a huge win! Not only did we gain accuracy, but it took way less computation. This one took
#
# * 156 seconds for PCA
# * 77 seconds for training
#
# or 233 total seconds while training with the original dataset took 1551 seconds.
